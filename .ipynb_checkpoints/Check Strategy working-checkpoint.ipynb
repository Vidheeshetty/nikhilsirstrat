# %%
# Quick setup for Jupyter notebooks - Copy and paste this into a notebook cell

import sys
import os

# Get current directory
current_dir = os.getcwd()
print(f"Current directory: {current_dir}")

# Determine project structure
if os.path.basename(current_dir) == "Jupyter Code":
    # We're in Jupyter Code folder, go up one level
    project_root = os.path.dirname(current_dir)
    src_path = os.path.join(project_root, 'src')
else:
    # We're in project root or somewhere else
    project_root = current_dir
    src_path = os.path.join(project_root, 'src')

# Add paths to sys.path
paths_added = []

if src_path not in sys.path and os.path.exists(src_path):
    sys.path.append(src_path)
    paths_added.append(src_path)
    print(f"✅ Added src path: {src_path}")

if project_root not in sys.path:
    sys.path.append(project_root)
    paths_added.append(project_root)
    print(f"✅ Added project root: {project_root}")

if not paths_added:
    print("ℹ️  All paths already in sys.path")

print(f"\n📁 Project structure:")
print(f"   Project root: {project_root}")
print(f"   Source directory: {src_path}")
print(f"   Current working directory: {os.getcwd()}")

print(f"\n🔧 Ready to import modules!")
print(f"   You can now use: from strategies.my_nse_strategy import MyNSEStrategy")
# Out:
# Current directory: /Volumes/T7/Code Repositories/NTbasedPlatform/Jupyter Code
# ✅ Added src path: /Volumes/T7/Code Repositories/NTbasedPlatform/src
# ✅ Added project root: /Volumes/T7/Code Repositories/NTbasedPlatform
#
# 📁 Project structure:
#    Project root: /Volumes/T7/Code Repositories/NTbasedPlatform
#    Source directory: /Volumes/T7/Code Repositories/NTbasedPlatform/src
#    Current working directory: /Volumes/T7/Code Repositories/NTbasedPlatform/Jupyter Code
#
# 🔧 Ready to import modules!
#    You can now use: from strategies.my_nse_strategy import MyNSEStrategy

# %%
# Now you can import your strategy modules
from strategies.my_nse_strategy import MyNSEStrategy, MyNSEStrategyConfig
from nautilus_trader.model import InstrumentId

# Test your strategy configuration
config = MyNSEStrategyConfig(
    instrument_id=InstrumentId.from_str("BANKNIFTY.OPT.26Jun2025.64000.CALL.NSE"),
    order_id_tag="001",
    oms_type="NETTING",
)

print("Strategy config created successfully!")
print(f"Instrument: {config.instrument_id}")
print(f"Position size: {config.position_size}")
# Out:
# Strategy config created successfully!
# Instrument: BANKNIFTY.OPT.26Jun2025.64000.CALL.NSE
# Position size: 1
