# %%
from nautilus_trader.accounting.accounts.margin import MarginAccount
help(MarginAccount)
# Out:
# Help on class MarginAccount in module nautilus_trader.accounting.accounts.margin:
#
# class MarginAccount(nautilus_trader.accounting.accounts.base.Account)
#  |  MarginAccount(AccountState event, bool calculate_account_state=False)
#  |  Provides a margin account.
#  |
#  |  Parameters
#  |  ----------
#  |  event : AccountState
#  |      The initial account state event.
#  |  calculate_account_state : bool, optional
#  |      If the account state should be calculated from order fills.
#  |
#  |  Raises
#  |  ------
#  |  ValueError
#  |      If `event.account_type` is not equal to ``MARGIN``.
#  |
#  |  Method resolution order:
#  |      MarginAccount
#  |      nautilus_trader.accounting.accounts.base.Account
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, /, *args, **kwargs)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  __reduce__ = __reduce_cython__(...)
#  |      MarginAccount.__reduce_cython__(self)
#  |
#  |  __reduce_cython__(self)
#  |      MarginAccount.__reduce_cython__(self)
#  |
#  |  __setstate__ = __setstate_cython__(...)
#  |      MarginAccount.__setstate_cython__(self, __pyx_state)
#  |
#  |  __setstate_cython__(self, __pyx_state)
#  |      MarginAccount.__setstate_cython__(self, __pyx_state)
#  |
#  |  balance_impact(self, instrument, quantity, price, order_side)
#  |      MarginAccount.balance_impact(self, Instrument instrument, Quantity quantity, Price price, OrderSide order_side) -> Money
#  |
#  |  calculate_commission(
#  |      self,
#  |      instrument,
#  |      last_qty,
#  |      last_px,
#  |      liquidity_side,
#  |      use_quote_for_inverse=False
#  |  )
#  |      MarginAccount.calculate_commission(self, Instrument instrument, Quantity last_qty, Price last_px, LiquiditySide liquidity_side, bool use_quote_for_inverse=False) -> Money
#  |      Calculate the commission generated from a transaction with the given
#  |      parameters.
#  |
#  |      Result will be in quote currency for standard instruments, or base
#  |      currency for inverse instruments.
#  |
#  |      Parameters
#  |      ----------
#  |      instrument : Instrument
#  |          The instrument for the calculation.
#  |      last_qty : Quantity
#  |          The transaction quantity.
#  |      last_px : Price
#  |          The transaction price.
#  |      liquidity_side : LiquiditySide {``MAKER``, ``TAKER``}
#  |          The liquidity side for the transaction.
#  |      use_quote_for_inverse : bool
#  |          If inverse instrument calculations use quote currency (instead of base).
#  |
#  |      Returns
#  |      -------
#  |      Money
#  |
#  |      Raises
#  |      ------
#  |      ValueError
#  |          If `liquidity_side` is ``NO_LIQUIDITY_SIDE``.
#  |
#  |  calculate_margin_init(
#  |      self,
#  |      instrument,
#  |      quantity,
#  |      price,
#  |      use_quote_for_inverse=False
#  |  )
#  |      MarginAccount.calculate_margin_init(self, Instrument instrument, Quantity quantity, Price price, bool use_quote_for_inverse=False) -> Money
#  |      Calculate the initial (order) margin.
#  |
#  |      Result will be in quote currency for standard instruments, or base
#  |      currency for inverse instruments.
#  |
#  |      Parameters
#  |      ----------
#  |      instrument : Instrument
#  |          The instrument for the calculation.
#  |      quantity : Quantity
#  |          The order quantity.
#  |      price : Price
#  |          The order price.
#  |      use_quote_for_inverse : bool
#  |          If inverse instrument calculations use quote currency (instead of base).
#  |
#  |      Returns
#  |      -------
#  |      Money
#  |
#  |  calculate_margin_maint(
#  |      self,
#  |      instrument,
#  |      side,
#  |      quantity,
#  |      price,
#  |      use_quote_for_inverse=False
#  |  )
#  |      MarginAccount.calculate_margin_maint(self, Instrument instrument, PositionSide side, Quantity quantity, Price price, bool use_quote_for_inverse=False) -> Money
#  |      Calculate the maintenance (position) margin.
#  |
#  |      Result will be in quote currency for standard instruments, or base
#  |      currency for inverse instruments.
#  |
#  |      Parameters
#  |      ----------
#  |      instrument : Instrument
#  |          The instrument for the calculation.
#  |      side : PositionSide {``LONG``, ``SHORT``}
#  |          The currency position side.
#  |      quantity : Quantity
#  |          The currency position quantity.
#  |      price : Price
#  |          The positions current price.
#  |      use_quote_for_inverse : bool
#  |          If inverse instrument calculations use quote currency (instead of base).
#  |
#  |      Returns
#  |      -------
#  |      Money
#  |
#  |  calculate_pnls(self, instrument, fill, position: 'Position | None' = None)
#  |      MarginAccount.calculate_pnls(self, Instrument instrument, OrderFilled fill, Position position: Position | None = None) -> list
#  |      Return the calculated PnL.
#  |
#  |      The calculation does not include any commissions.
#  |
#  |      Parameters
#  |      ----------
#  |      instrument : Instrument
#  |          The instrument for the calculation.
#  |      fill : OrderFilled
#  |          The fill for the calculation.
#  |      position : Position, optional
#  |          The position for the calculation.
#  |
#  |      Returns
#  |      -------
#  |      list[Money]
#  |
#  |  clear_margin(self, instrument_id)
#  |      MarginAccount.clear_margin(self, InstrumentId instrument_id) -> void
#  |      Clear the maintenance (position) margins for the given instrument ID.
#  |
#  |      Parameters
#  |      ----------
#  |      instrument_id : InstrumentId
#  |          The instrument for the maintenance margin to clear.
#  |
#  |      Warnings
#  |      --------
#  |      System method (not intended to be called by user code).
#  |
#  |  clear_margin_init(self, instrument_id)
#  |      MarginAccount.clear_margin_init(self, InstrumentId instrument_id) -> void
#  |      Clear the initial (order) margins for the given instrument ID.
#  |
#  |      Parameters
#  |      ----------
#  |      instrument_id : InstrumentId
#  |          The instrument for the initial margin to clear.
#  |
#  |      Warnings
#  |      --------
#  |      System method (not intended to be called by user code).
#  |
#  |  clear_margin_maint(self, instrument_id)
#  |      MarginAccount.clear_margin_maint(self, InstrumentId instrument_id) -> void
#  |      Clear the maintenance (position) margins for the given instrument ID.
#  |
#  |      Parameters
#  |      ----------
#  |      instrument_id : InstrumentId
#  |          The instrument for the maintenance margin to clear.
#  |
#  |      Warnings
#  |      --------
#  |      System method (not intended to be called by user code).
#  |
#  |  is_unleveraged(self, instrument_id)
#  |      MarginAccount.is_unleveraged(self, InstrumentId instrument_id) -> bool
#  |
#  |  leverage(self, instrument_id)
#  |      MarginAccount.leverage(self, InstrumentId instrument_id)
#  |      Return the leverage for the given instrument (if found).
#  |
#  |      Parameters
#  |      ----------
#  |      instrument_id : InstrumentId
#  |          The instrument ID for the leverage.
#  |
#  |      Returns
#  |      -------
#  |      Decimal or ``None``
#  |
#  |  leverages(self)
#  |      MarginAccount.leverages(self) -> dict
#  |      Return the account leverages.
#  |
#  |      Returns
#  |      -------
#  |      dict[InstrumentId, Decimal]
#  |
#  |  margin(self, instrument_id)
#  |      MarginAccount.margin(self, InstrumentId instrument_id) -> MarginBalance
#  |      Return the current margin balance.
#  |
#  |      Parameters
#  |      ----------
#  |      instrument_id : InstrumentId
#  |          The instrument ID for the query.
#  |
#  |      Returns
#  |      -------
#  |      MarginBalance or ``None``
#  |
#  |      Warnings
#  |      --------
#  |      Returns ``None`` if there is no applicable information for the query,
#  |      rather than `MarginBalance` with zero amounts.
#  |
#  |  margin_init(self, instrument_id)
#  |      MarginAccount.margin_init(self, InstrumentId instrument_id) -> Money
#  |      Return the current initial (order) margin.
#  |
#  |      Parameters
#  |      ----------
#  |      instrument_id : InstrumentId
#  |          The instrument ID for the query.
#  |
#  |      Returns
#  |      -------
#  |      Money or ``None``
#  |
#  |      Warnings
#  |      --------
#  |      Returns ``None`` if there is no applicable information for the query,
#  |      rather than `Money` of zero amount.
#  |
#  |  margin_maint(self, instrument_id)
#  |      MarginAccount.margin_maint(self, InstrumentId instrument_id) -> Money
#  |      Return the current maintenance (position) margin.
#  |
#  |      Parameters
#  |      ----------
#  |      instrument_id : InstrumentId
#  |          The instrument ID for the query.
#  |
#  |      Returns
#  |      -------
#  |      Money or ``None``
#  |
#  |      Warnings
#  |      --------
#  |      Returns ``None`` if there is no applicable information for the query,
#  |      rather than `Money` of zero amount.
#  |
#  |  margins(self)
#  |      MarginAccount.margins(self) -> dict
#  |      Return the initial (order) margins for the account.
#  |
#  |      Returns
#  |      -------
#  |      dict[InstrumentId, Money]
#  |
#  |  margins_init(self)
#  |      MarginAccount.margins_init(self) -> dict
#  |      Return the initial (order) margins for the account.
#  |
#  |      Returns
#  |      -------
#  |      dict[InstrumentId, Money]
#  |
#  |  margins_maint(self)
#  |      MarginAccount.margins_maint(self) -> dict
#  |      Return the maintenance (position) margins for the account.
#  |
#  |      Returns
#  |      -------
#  |      dict[InstrumentId, Money]
#  |
#  |  set_default_leverage(self, leverage: 'Decimal')
#  |      MarginAccount.set_default_leverage(self, leverage: Decimal) -> void
#  |      Set the default leverage for the account (if not specified by instrument).
#  |
#  |      Parameters
#  |      ----------
#  |      leverage : Decimal
#  |          The default leverage value
#  |
#  |      Returns
#  |      -------
#  |      TypeError
#  |          If leverage is not of type `Decimal`.
#  |      ValueError
#  |          If leverage is not >= 1.
#  |
#  |  set_leverage(self, instrument_id, leverage: 'Decimal')
#  |      MarginAccount.set_leverage(self, InstrumentId instrument_id, leverage: Decimal) -> void
#  |      Set the leverage for the given instrument.
#  |
#  |      Parameters
#  |      ----------
#  |      instrument_id : InstrumentId
#  |          The instrument for the leverage.
#  |      leverage : Decimal
#  |          The leverage value
#  |
#  |      Returns
#  |      -------
#  |      TypeError
#  |          If leverage is not of type `Decimal`.
#  |      ValueError
#  |          If leverage is not >= 1.
#  |
#  |  update_margin(self, margin)
#  |      MarginAccount.update_margin(self, MarginBalance margin) -> void
#  |      Update the margin balance.
#  |
#  |      Parameters
#  |      ----------
#  |      margin : MarginBalance
#  |
#  |      Warnings
#  |      --------
#  |      System method (not intended to be called by user code).
#  |
#  |  update_margin_init(self, instrument_id, margin_init)
#  |      MarginAccount.update_margin_init(self, InstrumentId instrument_id, Money margin_init) -> void
#  |      Update the initial (order) margin.
#  |
#  |      Parameters
#  |      ----------
#  |      instrument_id : InstrumentId
#  |          The instrument ID for the update.
#  |      margin_init : Money
#  |          The current initial (order) margin for the instrument.
#  |
#  |      Raises
#  |      ------
#  |      ValueError
#  |          If `margin_init` is negative (< 0).
#  |
#  |      Warnings
#  |      --------
#  |      System method (not intended to be called by user code).
#  |
#  |  update_margin_maint(self, instrument_id, margin_maint)
#  |      MarginAccount.update_margin_maint(self, InstrumentId instrument_id, Money margin_maint) -> void
#  |      Update the maintenance (position) margin.
#  |
#  |      Parameters
#  |      ----------
#  |      instrument_id : InstrumentId
#  |          The instrument ID for the update.
#  |      margin_maint : Money
#  |          The current maintenance (position) margin for the instrument.
#  |
#  |      Raises
#  |      ------
#  |      ValueError
#  |          If `margin_maint` is negative (< 0).
#  |
#  |      Warnings
#  |      --------
#  |      System method (not intended to be called by user code).
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods defined here:
#  |
#  |  __new__(*args, **kwargs)
#  |      Create and return a new object.  See help(type) for accurate signature.
#  |
#  |  from_dict(values)
#  |      MarginAccount.from_dict(dict values)
#  |
#  |  to_dict(obj)
#  |      MarginAccount.to_dict(MarginAccount obj)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  default_leverage
#  |      The accounts default leverage setting.
#  |
#  |      :returns: `Decimal`
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  __pyx_vtable__ = <capsule object NULL>
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from nautilus_trader.accounting.accounts.base.Account:
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
#  |  __hash__(self, /)
#  |      Return hash(self).
#  |
#  |  __le__(self, value, /)
#  |      Return self<=value.
#  |
#  |  __lt__(self, value, /)
#  |      Return self<value.
#  |
#  |  __ne__(self, value, /)
#  |      Return self!=value.
#  |
#  |  __repr__(self, /)
#  |      Return repr(self).
#  |
#  |  apply(self, event)
#  |      Account.apply(self, AccountState event) -> void
#  |      Apply the given account event to the account.
#  |
#  |      Parameters
#  |      ----------
#  |      event : AccountState
#  |          The account event to apply.
#  |
#  |      Raises
#  |      ------
#  |      ValueError
#  |          If `event.account_type` is not equal to `self.type`.
#  |      ValueError
#  |          If `event.account_id` is not equal to `self.id`.
#  |      ValueError
#  |          If `event.base_currency` is not equal to `self.base_currency`.
#  |
#  |      Warnings
#  |      --------
#  |      System method (not intended to be called by user code).
#  |
#  |  balance(self, currency=None)
#  |      Account.balance(self, Currency currency=None) -> AccountBalance
#  |      Return the current account balance total.
#  |
#  |      For multi-currency accounts, specify the currency for the query.
#  |
#  |      Parameters
#  |      ----------
#  |      currency : Currency, optional
#  |          The currency for the query. If ``None`` then will use the default
#  |          currency (if set).
#  |
#  |      Returns
#  |      -------
#  |      AccountBalance or ``None``
#  |
#  |      Raises
#  |      ------
#  |      ValueError
#  |          If `currency` is ``None`` and `base_currency` is ``None``.
#  |
#  |      Warnings
#  |      --------
#  |      Returns ``None`` if there is no applicable information for the query,
#  |      rather than `Money` of zero amount.
#  |
#  |  balance_free(self, currency=None)
#  |      Account.balance_free(self, Currency currency=None) -> Money
#  |      Return the account balance free.
#  |
#  |      For multi-currency accounts, specify the currency for the query.
#  |
#  |      Parameters
#  |      ----------
#  |      currency : Currency, optional
#  |          The currency for the query. If ``None`` then will use the default
#  |          currency (if set).
#  |
#  |      Returns
#  |      -------
#  |      Money or ``None``
#  |
#  |      Raises
#  |      ------
#  |      ValueError
#  |          If `currency` is ``None`` and `base_currency` is ``None``.
#  |
#  |      Warnings
#  |      --------
#  |      Returns ``None`` if there is no applicable information for the query,
#  |      rather than `Money` of zero amount.
#  |
#  |  balance_locked(self, currency=None)
#  |      Account.balance_locked(self, Currency currency=None) -> Money
#  |      Return the account balance locked.
#  |
#  |      For multi-currency accounts, specify the currency for the query.
#  |
#  |      Parameters
#  |      ----------
#  |      currency : Currency, optional
#  |          The currency for the query. If ``None`` then will use the default
#  |          currency (if set).
#  |
#  |      Returns
#  |      -------
#  |      Money or ``None``
#  |
#  |      Raises
#  |      ------
#  |      ValueError
#  |          If `currency` is ``None`` and `base_currency` is ``None``.
#  |
#  |      Warnings
#  |      --------
#  |      Returns ``None`` if there is no applicable information for the query,
#  |      rather than `Money` of zero amount.
#  |
#  |  balance_total(self, currency=None)
#  |      Account.balance_total(self, Currency currency=None) -> Money
#  |      Return the current account balance total.
#  |
#  |      For multi-currency accounts, specify the currency for the query.
#  |
#  |      Parameters
#  |      ----------
#  |      currency : Currency, optional
#  |          The currency for the query. If ``None`` then will use the default
#  |          currency (if set).
#  |
#  |      Returns
#  |      -------
#  |      Money or ``None``
#  |
#  |      Raises
#  |      ------
#  |      ValueError
#  |          If `currency` is ``None`` and `base_currency` is ``None``.
#  |
#  |      Warnings
#  |      --------
#  |      Returns ``None`` if there is no applicable information for the query,
#  |      rather than `Money` of zero amount.
#  |
#  |  balances(self)
#  |      Account.balances(self) -> dict
#  |      Return the account balances totals.
#  |
#  |      Returns
#  |      -------
#  |      dict[Currency, Money]
#  |
#  |  balances_free(self)
#  |      Account.balances_free(self) -> dict
#  |      Return the account balances free.
#  |
#  |      Returns
#  |      -------
#  |      dict[Currency, Money]
#  |
#  |  balances_locked(self)
#  |      Account.balances_locked(self) -> dict
#  |      Return the account balances locked.
#  |
#  |      Returns
#  |      -------
#  |      dict[Currency, Money]
#  |
#  |  balances_total(self)
#  |      Account.balances_total(self) -> dict
#  |      Return the account balances totals.
#  |
#  |      Returns
#  |      -------
#  |      dict[Currency, Money]
#  |
#  |  commission(self, currency)
#  |      Account.commission(self, Currency currency) -> Money
#  |      Return the total commissions for the given currency.
#  |
#  |      Parameters
#  |      ----------
#  |      currency : Currency
#  |          The currency for the commission.
#  |
#  |      Returns
#  |      -------
#  |      Money or ``None``
#  |
#  |  commissions(self)
#  |      Account.commissions(self) -> dict
#  |      Return the total commissions for the account.
#  |
#  |  currencies(self)
#  |      Account.currencies(self) -> list
#  |      Return the account currencies.
#  |
#  |      Returns
#  |      -------
#  |      list[Currency]
#  |
#  |  purge_account_events(self, ts_now, lookback_secs=0)
#  |      Account.purge_account_events(self, uint64_t ts_now, uint64_t lookback_secs=0) -> void
#  |      Purge all account state events which are outside the lookback window.
#  |
#  |      Guaranteed to retain at least the latest event.
#  |
#  |      Parameters
#  |      ----------
#  |      ts_now : uint64_t
#  |          The current UNIX timestamp (nanoseconds).
#  |      lookback_secs : uint64_t, default 0
#  |          The purge lookback window (seconds) from when the account state event occurred.
#  |          Only events which are outside the lookback window will be purged.
#  |          A value of 0 means purge all account state events.
#  |
#  |  starting_balances(self)
#  |      Account.starting_balances(self) -> dict
#  |      Return the account starting balances.
#  |
#  |      Returns
#  |      -------
#  |      dict[Currency, Money]
#  |
#  |  update_balances(self, balances, allow_zero=True)
#  |      Account.update_balances(self, list balances, bool allow_zero=True) -> void
#  |      Update the account balances.
#  |
#  |      There is no guarantee that every account currency is included in the
#  |      given balances, therefore we only update included balances.
#  |
#  |      Parameters
#  |      ----------
#  |      balances : list[AccountBalance]
#  |          The balances for the update.
#  |      allow_zero : bool, default True
#  |          If zero balances are allowed (will then just clear the assets balance).
#  |
#  |      Raises
#  |      ------
#  |      ValueError
#  |          If `balances` is empty.
#  |
#  |  update_commissions(self, commission)
#  |      Account.update_commissions(self, Money commission) -> void
#  |      Update the commissions.
#  |
#  |      Can be negative which represents credited commission.
#  |
#  |      Parameters
#  |      ----------
#  |      commission : Money
#  |          The commission to update with.
#  |
#  |      Warnings
#  |      --------
#  |      System method (not intended to be called by user code).
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from nautilus_trader.accounting.accounts.base.Account:
#  |
#  |  base_currency
#  |      The accounts base currency (``None`` for multi-currency accounts).
#  |
#  |      :returns: `Currency` or ``None``
#  |
#  |  calculate_account_state
#  |      If the accounts state should be calculated by Nautilus.
#  |
#  |      :returns: `bool`
#  |
#  |  event_count
#  |      Return the count of events.
#  |
#  |      Returns
#  |      -------
#  |      int
#  |
#  |  events
#  |      Return all events received by the account.
#  |
#  |      Returns
#  |      -------
#  |      list[AccountState]
#  |
#  |  id
#  |      The accounts ID.
#  |
#  |      :returns: `AccountId`
#  |
#  |  is_cash_account
#  |      If the account is a type of ``CASH`` account.
#  |
#  |  is_margin_account
#  |      If the account is a type of ``MARGIN`` account.
#  |
#  |  last_event
#  |      Return the accounts last state event.
#  |
#  |      Returns
#  |      -------
#  |      AccountState
#  |
#  |  type
#  |      The accounts type.
#  |
#  |      :returns: `AccountType`

# %%
import os
import pandas as pd
from datetime import datetime

# Nautilus imports for constructing data and instruments
from nautilus_trader.model.data import QuoteTick
from nautilus_trader.model.identifiers import InstrumentId
from nautilus_trader.model.objects import Price, Quantity, Currency
from nautilus_trader.core.datetime import dt_to_unix_nanos
from nautilus_trader.persistence.catalog.parquet import ParquetDataCatalog
from nautilus_trader.model.instruments.option_contract import OptionContract
from nautilus_trader.model.identifiers import InstrumentId, Symbol, Venue
from nautilus_trader.model.enums import AssetClass, OptionKind
from nautilus_trader.core.datetime import dt_to_unix_nanos
from datetime import datetime, timezone

import logging

# Enable debug-level logs
logging.basicConfig(level=logging.DEBUG)

# --- Set directories
csv_dir = "data/nse"
catalog_dir = "catalog"
catalog_meta_dir = "catalog-meta"
os.makedirs(catalog_dir, exist_ok=True)
os.makedirs(catalog_meta_dir, exist_ok=True)

# --- Initialize Parquet catalog to store core data (quote ticks and instruments)
catalog = ParquetDataCatalog(catalog_dir)

# --- Storage lists
all_ticks = []                 # Stores QuoteTick instances
instrument_ids = set()         # Keeps track of all unique instrument IDs
meta_records = []              # Stores auxiliary/meta data as dict rows

# --- Loop through each CSV file in the input directory
for fname in os.listdir(csv_dir):
    if not fname.endswith(".csv") or fname.startswith("._"):
        continue

    print(f"Reading {fname}")
    df = pd.read_csv(os.path.join(csv_dir, fname))

    # Convert timestamps to nanoseconds since epoch (UNIX time)
    df["timestamp"] = pd.to_datetime(df["timestamp"], format="%m/%d/%y %H:%M")
    df["timestamp"] = df["timestamp"].apply(dt_to_unix_nanos)

    # --- Parse rows into QuoteTick objects
    for _, row in df.iterrows():
        try:
             
            iid_str = row["symbol"].strip()
            parts = iid_str.split(".")
            symbol = parts[0]               # e.g. BANKNIFTY
            venue = parts[1]                # e.g. NSE
            type = parts[2]                 # e.g. OPTION
            expiry_raw = parts[3]           # e.g. 26Jun2025
            strike = float(parts[4])
            right = parts[5].upper()        # CALL or PUT
            symbolplus = f"{symbol}.{type}.{expiry_raw}.{int(strike)}.{right}"
            instrument_id = InstrumentId(symbol=Symbol(symbolplus), venue=Venue(venue))

            # Setup price and size values
            bid_val = float(row["bid"])
            ask_val = float(row["ask"])
            bid_precision = 2
            ask_precision = 2
            bid_size_val = float(row.get("bid_size", 1))
            ask_size_val = float(row.get("ask_size", 1))
            size_precision = 0

            # Create QuoteTick object
            tick = QuoteTick(
                instrument_id=instrument_id,
                ts_event=int(row["timestamp"]),
                ts_init=int(row["timestamp"]),
                bid_price=Price(int(bid_val * 10**bid_precision), bid_precision),
                ask_price=Price(int(ask_val * 10**ask_precision), ask_precision),
                bid_size=Quantity(int(bid_size_val * 10**size_precision), size_precision),
                ask_size=Quantity(int(ask_size_val * 10**size_precision), size_precision),
            )

            all_ticks.append(tick)
          
            instrument_ids.add(instrument_id)

            # Save the meta fields separately
            meta_records.append({
                "instrument_id": f"{symbolplus}.{venue}",
                "timestamp": row["timestamp"],
                "impliedVolatility": row.get("impliedVolatility"),
                "openInterest": row.get("openInterest"),
                "last": row.get("last"),
                "pChange": row.get("pChange"),
            })

        except Exception as e:
            print(f"⚠️ Skipping row due to tick parsing error: {e}")

# --- Build dummy instruments using OptionContract.from_dict
# This will store instrument metadata needed by the engine
print(list(instrument_ids)[0])
print(list(meta_records)[0])
print(all_ticks[0])
# Example loop for just 1 instrument ID
dummy_instruments = []
for iid in instrument_ids:
    try:
        print(f"🔍 Processing: {iid.value}")
        parts = iid.value.split(".")
        symbol = parts[0]               # e.g. BANKNIFTY
        type = parts[1] 
        expiry_raw = parts[2]           # e.g. 26Jun2025
        strike = float(parts[3])
        right = parts[4].upper()        # CALL or PUT
        venue = parts[5]               # e.g. NSE
        symbolplus = f"{symbol}.{type}.{expiry_raw}.{int(strike)}.{right}"

        expiry_dt = datetime.strptime(expiry_raw, "%d%b%Y")
        expiry_utc = expiry_dt.replace(hour=15, minute=30, tzinfo=timezone.utc)
        now_utc = datetime.now(timezone.utc)

        option = OptionContract(
            instrument_id=InstrumentId(symbol=Symbol(symbolplus ), venue=Venue(venue)),
            raw_symbol=Symbol(symbol),
            asset_class=AssetClass.INDEX,     # Same as example
            exchange=venue,
            currency=Currency.from_str("INR"),
            price_precision=2,
            price_increment=Price.from_str("0.05"),
            multiplier=Quantity.from_int(15),
            lot_size=Quantity.from_int(1),
            underlying=f"{symbol}.{venue}.INDEX",
            option_kind=OptionKind[right],
            strike_price=Price.from_str(str(strike)),
            activation_ns=0,  # Set to 0 to make it always active
            expiration_ns=dt_to_unix_nanos(expiry_utc),
            ts_event=dt_to_unix_nanos(now_utc),
            ts_init=dt_to_unix_nanos(now_utc),
        )

        print(f"✅ Created OptionContract: {option.id}")
        dummy_instruments.append(option)
    except Exception as e:
        print(f"⚠️ Skipping {iid.value} due to instrument creation error: {e}")

catalog.write_data(dummy_instruments)
catalog.write_data(all_ticks)
# --- Write meta-data (IV, OI, etc.) to separate catalog-meta folder
meta_df = pd.DataFrame(meta_records)
meta_df.to_parquet(os.path.join(catalog_meta_dir, "tick_metadata.parquet"), index=False)

print(f"\n✅ Written {len(all_ticks)} quote ticks to {catalog_dir}/")
print(f"✅ Written {len(meta_df)} metadata records to {catalog_meta_dir}/")
print(f"✅ Written {len(dummy_instruments)} dummy instruments")

# Create a DataFrame of instrument metadata
instrument_meta = [{
    "instrument_id": str(inst.id),
    "symbol": str(inst.raw_symbol),
    "strike": float(inst.strike_price.value / (10 ** inst.strike_price.precision)),
    "expiry": inst.expiration_ns,
    "option_kind": inst.option_kind.name,
    "venue": inst.exchange,
    "activation_ns": inst.activation_ns,
} for inst in dummy_instruments]

df_instruments = pd.DataFrame(instrument_meta)
df_instruments.to_parquet(os.path.join(catalog_meta_dir, "instruments.parquet"), index=False)

print(f"✅ Written {len(dummy_instruments)} dummy instruments to instrument metadata")
# Out:
# Reading Mock_15-Min_Intraday_Option_Chain.csv
# BANKNIFTY.OPT.26Jun2025.55000.CALL.NSE
# {'instrument_id': 'BANKNIFTY.OPT.26Jun2025.40500.CALL.NSE', 'timestamp': 1750248000000000000, 'impliedVolatility': 19.78589168849317, 'openInterest': None, 'last': 15149.69827987147, 'pChange': 0.5961395680525068}
# BANKNIFTY.OPT.26Jun2025.40500.CALL.NSE,1519815.00,1562036.00,1,1,1750248000000000000
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.55000.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.55000.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.48700.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.48700.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.60000.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.60000.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.61700.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.61700.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.59100.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.59100.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.55400.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.55400.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.58800.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.58800.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.57000.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.57000.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.52700.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.52700.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.52400.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.52400.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.55100.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.55100.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.47900.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.47900.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.58100.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.58100.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.60400.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.60400.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.61400.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.61400.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.42000.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.42000.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.51600.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.51600.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.56800.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.56800.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.47600.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.47600.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.51700.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.51700.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.50400.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.50400.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.54200.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.54200.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.60500.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.60500.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.44500.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.44500.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.60300.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.60300.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.47200.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.47200.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.46900.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.46900.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.52600.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.52600.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.53000.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.53000.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.56500.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.56500.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.51800.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.51800.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.42500.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.42500.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.61000.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.61000.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.56900.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.56900.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.51900.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.51900.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.50800.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.50800.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.61100.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.61100.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.59500.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.59500.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.48500.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.48500.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.52100.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.52100.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.53100.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.53100.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.43500.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.43500.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.46100.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.46100.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.47700.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.47700.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.56200.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.56200.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.51500.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.51500.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.52300.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.52300.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.48900.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.48900.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.49200.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.49200.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.49500.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.49500.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.51300.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.51300.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.45300.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.45300.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.50300.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.50300.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.58600.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.58600.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.63500.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.63500.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.45500.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.45500.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.54100.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.54100.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.55800.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.55800.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.53500.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.53500.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.47100.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.47100.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.48200.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.48200.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.57500.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.57500.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.51400.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.51400.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.53800.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.53800.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.47000.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.47000.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.52500.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.52500.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.57100.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.57100.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.56600.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.56600.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.61500.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.61500.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.64500.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.64500.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.50000.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.50000.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.48300.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.48300.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.47800.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.47800.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.51200.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.51200.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.63000.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.63000.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.56700.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.56700.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.46700.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.46700.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.59400.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.59400.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.50100.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.50100.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.58900.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.58900.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.50600.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.50600.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.57300.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.57300.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.46000.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.46000.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.55500.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.55500.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.58200.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.58200.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.43000.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.43000.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.54000.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.54000.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.54500.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.54500.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.58000.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.58000.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.57600.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.57600.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.61200.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.61200.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.55600.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.55600.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.50200.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.50200.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.45200.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.45200.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.44900.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.44900.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.45100.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.45100.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.48600.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.48600.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.54700.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.54700.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.55200.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.55200.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.55700.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.55700.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.56300.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.56300.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.47400.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.47400.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.46400.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.46400.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.53900.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.53900.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.60700.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.60700.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.57800.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.57800.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.53300.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.53300.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.45600.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.45600.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.58300.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.58300.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.61800.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.61800.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.48400.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.48400.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.60200.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.60200.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.47500.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.47500.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.49600.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.49600.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.49900.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.49900.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.53200.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.53200.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.49400.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.49400.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.64000.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.64000.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.49700.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.49700.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.58700.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.58700.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.61600.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.61600.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.54600.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.54600.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.49300.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.49300.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.49100.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.49100.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.54400.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.54400.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.62500.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.62500.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.45800.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.45800.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.60900.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.60900.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.46800.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.46800.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.50700.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.50700.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.46300.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.46300.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.53700.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.53700.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.45000.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.45000.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.45700.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.45700.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.59200.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.59200.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.59900.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.59900.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.60800.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.60800.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.50900.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.50900.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.59000.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.59000.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.48100.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.48100.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.46200.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.46200.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.52800.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.52800.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.57900.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.57900.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.47300.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.47300.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.56100.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.56100.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.54300.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.54300.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.57400.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.57400.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.51100.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.51100.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.45400.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.45400.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.59300.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.59300.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.56000.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.56000.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.48000.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.48000.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.53400.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.53400.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.57200.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.57200.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.61300.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.61300.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.49800.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.49800.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.50500.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.50500.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.56400.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.56400.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.62000.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.62000.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.40500.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.40500.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.51000.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.51000.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.52200.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.52200.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.52000.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.52000.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.55900.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.55900.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.58400.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.58400.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.49000.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.49000.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.46500.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.46500.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.57700.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.57700.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.53600.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.53600.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.46600.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.46600.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.59700.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.59700.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.55300.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.55300.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.54800.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.54800.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.45900.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.45900.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.60100.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.60100.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.59600.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.59600.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.54900.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.54900.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.52900.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.52900.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.44000.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.44000.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.60600.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.60600.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.59800.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.59800.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.48800.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.48800.CALL.NSE
# 🔍 Processing: BANKNIFTY.OPT.26Jun2025.58500.CALL.NSE
# ✅ Created OptionContract: BANKNIFTY.OPT.26Jun2025.58500.CALL.NSE
#
# ✅ Written 1830 quote ticks to catalog/
# ✅ Written 1830 metadata records to catalog-meta/
# ✅ Written 183 dummy instruments

# %%
# Step 1: Add strategy to engine
from decimal import Decimal
from nautilus_trader.backtest.engine import BacktestEngine
from nautilus_trader.config import BacktestEngineConfig, LoggingConfig
from nautilus_trader.model import InstrumentId, TraderId
from nautilus_trader.model.enums import AccountType, OmsType
from nautilus_trader.model.objects import Money
from nautilus_trader.model.currencies import INR
from nautilus_trader.model.identifiers import Venue
from nautilus_trader.persistence.catalog.parquet import ParquetDataCatalog

from src.strategies.my_nse_strategy import MyNSEStrategy, MyNSEStrategyConfig

# Step 1: Backtest engine config with debug logging
engine_config = BacktestEngineConfig(
    trader_id=TraderId("BACKTEST_TRADER-001"),
    logging=LoggingConfig(log_level="DEBUG"),
)

engine = BacktestEngine(config=engine_config)
# Out:
# 2025-06-22T07:08:35.871630000Z [INFO] BACKTEST_TRADER-001.BacktestEngine: =================================================================
# 2025-06-22T07:08:35
<nautilus_trader.portfolio.portfolio.Portfolio object at 0x145870860>>
# 2025-06-22T07:08:35.892918000Z [DEBUG] BACKTEST_TRADER-001.MessageBus: Added endpoint 'Portfolio.update_order' <bound method Portfolio.update_order of <nautilus_trader.portfolio.portfolio.Portfolio object at 0x145870860>>
# 2025-06-22T07:08:35.892919000Z [DEBUG] BACKTEST_TRADER-001.MessageBus: Added endpoint 'Portfolio.update_position' <bound method Portfolio.update_position of <nautilus_trader.portfolio.portfolio.Portfolio object at 0x145870860>>
# 2025-06-22T07:08:35.892924000Z [DEBUG] BACKTEST_TRADER-001.MessageBus: Added Subscription(topic=events.order.*, handler=<bound method Portfolio.on_order_event of <nautilus_trader.portfolio.portfolio.Portfolio object at 0x145870860>>, priority=10)
# 2025-06-22T07:08:35.892927000Z [DEBUG] BACKTEST_TRADER-001.MessageBus: Added Subscription(topic=events.position.*, handler=<bound method Portfolio.on_position_event of <nautilus_trader.portfolio.portfolio.Portfolio object at 0x145870860>>, priority=10)
# 2025-06-22T07:08:35.892931000Z [DEBUG] BACKTEST_TRADER-001.MessageBus: Added Subscription(topic=data.quotes.*, handler=<bound method Portfolio.update_quote_tick of <nautilus_trader.portfolio.portfolio.Portfolio object at 0x145870860>>, priority=10)
# 2025-06-22T07:08:35.892935000Z [DEBUG] BACKTEST_TRADER-001.MessageBus: Added Subscription(topic=data.bars.*EXTERNAL, handler=<bound method Portfolio.update_bar of <nautilus_trader.portfolio.portfolio.Portfolio object at 0x145870860>>, priority=10)
# 2025-06-22T07:08:35.893000000Z [INFO] BACKTEST_TRADER-001.DataEngine: READY
# 2025-06-22T07:08:35.893049000Z [DEBUG] BACKTEST_TRADER-001.MessageBus: Added endpoint 'DataEngine.execute' <bound method DataEngine.execute of DataEngine(DataEngine)>
# 2025-06-22T07:08:35.893051000Z [DEBUG] BACKTEST_TRADER-001.MessageBus: Added endpoint 'DataEngine.process' <bound method DataEngine.process of DataEngine(DataEngine)>
# 2025-06-22T07:08:35.893052000Z [DEBUG] BACKTEST_TRADER-001.MessageBus: Added endpoint 'DataEngine.request' <bound method DataEngine.request of DataEngine(DataEngine)>
# 2025-06-22T07:08:35.893053000Z [DEBUG] BACKTEST_TRADER-001.MessageBus: Added endpoint 'DataEngine.response' <bound method DataEngine.response of DataEngine(DataEngine)>
# 2025-06-22T07:08:35.893080000Z [INFO] BACKTEST_TRADER-001.RiskEngine: READY
# 2025-06-22T07:08:35.893093000Z [INFO] BACKTEST_TRADER-001.RiskEngine: TradingState is ACTIVE
# 2025-06-22T07:08:35.893538000Z [INFO] BACKTEST_TRADER-001.Throttler-ORDER_SUBMIT_THROTTLER: READY
# 2025-06-22T07:08:35.893560000Z [INFO] BACKTEST_TRADER-001.RiskEngine: Set MAX_ORDER_SUBMIT_RATE: 100/00:00:01
# 2025-06-22T07:08:35.893574000Z [INFO] BACKTEST_TRADER-001.Throttler-ORDER_MODIFY_THROTTLER: READY
# 2025-06-22T07:08:35.893585000Z [INFO] BACKTEST_TRADER-001.RiskEngine: Set MAX_ORDER_MODIFY_RATE: 100/00:00:01
# 2025-06-22T07:08:35.893589000Z [DEBUG] BACKTEST_TRADER-001.MessageBus: Added endpoint 'RiskEngine.execute' <bound method RiskEngine.execute of RiskEngine(RiskEngine)>
# 2025-06-22T07:08:35.893591000Z [DEBUG] BACKTEST_TRADER-001.MessageBus: Added endpoint 'RiskEngine.process' <bound method RiskEngine.process of RiskEngine(RiskEngine)>
# 2025-06-22T07:08:35.893595000Z [DEBUG] BACKTEST_TRADER-001.MessageBus: Added Subscription(topic=events.order.*, handler=<bound method RiskEngine._handle_event of RiskEngine(RiskEngine)>, priority=10)
# 2025-06-22T07:08:35.893597000Z [DEBUG] BACKTEST_TRADER-001.MessageBus: Added Subscription(topic=events.position.*, handler=<bound method RiskEngine._handle_event of RiskEngine(RiskEngine)>, priority=10)
# 2025-06-22T07:08:35.893624000Z [INFO] BACKTEST_TRADER-001.ExecEngine: READY
# 2025-06-22T07:08:35.893647000Z [INFO] BACKTEST_TRADER-001.ExecEngine: config.snapshot_orders=False
# 2025-06-22T07:08:35.893648000Z [INFO] BACKTEST_TRADER-001.ExecEngine: config.snapshot_positions=False
# 2025-06-22T07:08:35.893649000Z [INFO] BACKTEST_TRADER-001.ExecEngine: config.snapshot_positions_interval_secs=None
# 2025-06-22T07:08:35.893651000Z [DEBUG] BACKTEST_TRADER-001.MessageBus: Added endpoint 'ExecEngine.execute' <bound method ExecutionEngine.execute of ExecutionEngine(ExecEngine)>
# 2025-06-22T07:08:35.893653000Z [DEBUG] BACKTEST_TRADER-001.MessageBus: Added endpoint 'ExecEngine.process' <bound method ExecutionEngine.process of ExecutionEngine(ExecEngine)>
# 2025-06-22T07:08:35.894282000Z [DEBUG] BACKTEST_TRADER-001.Cache: Clearing index
# 2025-06-22T07:08:35.894284000Z [DEBUG] BACKTEST_TRADER-001.Cache: Cleared index
# 2025-06-22T07:08:35.894507000Z [DEBUG] BACKTEST_TRADER-001.Cache: Loading general cache from database
# 2025-06-22T07:08:35.894514000Z [INFO] BACKTEST_TRADER-001.Cache: Cached 0 general objects from database
# 2025-06-22T07:08:35.894515000Z [DEBUG] BACKTEST_TRADER-001.Cache: Loading currencies from database
# 2025-06-22T07:08:35.894517000Z [INFO] BACKTEST_TRADER-001.Cache: Cached 0 currencies from database
# 2025-06-22T07:08:35.894518000Z [DEBUG] BACKTEST_TRADER-001.Cache: Loading instruments from database
# 2025-06-22T07:08:35.894519000Z [INFO] BACKTEST_TRADER-001.Cache: Cached 0 instruments from database
# 2025-06-22T07:08:35.894519001Z [DEBUG] BACKTEST_TRADER-001.Cache: Loading accounts from database
# 2025-06-22T07:08:35.894519002Z [INFO] BACKTEST_TRADER-001.Cache: Cached 0 accounts from database
# 2025-06-22T07:08:35.894520000Z [DEBUG] BACKTEST_TRADER-001.Cache: Loading orders from database
# 2025-06-22T07:08:35.894741000Z [INFO] BACKTEST_TRADER-001.Cache: Cached 0 orders from database
# 2025-06-22T07:08:35.894745000Z [DEBUG] BACKTEST_TRADER-001.Cache: Loading order lists
# 2025-06-22T07:08:35.894746000Z [INFO] BACKTEST_TRADER-001.Cache: Cached 0 order lists from database
# 2025-06-22T07:08:35.894747000Z [DEBUG] BACKTEST_TRADER-001.Cache: Loading positions from database
# 2025-06-22T07:08:35.894747001Z [INFO] BACKTEST_TRADER-001.Cache: Cached 0 positions from database
# 2025-06-22T07:08:35.894747002Z [DEBUG] BACKTEST_TRADER-001.Cache: Building index
# 2025-06-22T07:08:35.894755000Z [DEBUG] BACKTEST_TRADER-001.Cache: Index built in 0.000s
# 2025-06-22T07:08:35.894756000Z [INFO] BACKTEST_TRADER-001.Cache: Checking data integrity
# 2025-06-22T07:08:35.895202000Z [INFO] BACKTEST_TRADER-001.Cache: Integrity check passed in 444μs
# 2025-06-22T07:08:35.895213000Z [INFO] BACKTEST_TRADER-001.ExecEngine: Loaded cache in 2ms
# 2025-06-22T07:08:35.895544000Z [INFO] BACKTEST_TRADER-001.OrderEmulator: READY
# 2025-06-22T07:08:35.895585000Z [DEBUG] BACKTEST_TRADER-001.MessageBus: Added endpoint 'OrderEmulator.execute' <bound method OrderEmulator.execute of OrderEmulator(OrderEmulator)>
# 2025-06-22T07:08:35.895599000Z [INFO] BACKTEST_TRADER-001.BACKTEST_TRADER-001: READY
# 2025-06-22T07:08:35.895619000Z [INFO] BACKTEST_TRADER-001.BacktestEngine: Initialized in 48ms
# 2025-06-22T07:08:35.895635000Z [DEBUG] BACKTEST_TRADER-001.MessageBus: Added endpoint 'BacktestEngine.execute' <bound method BacktestEngine._handle_data_command of <nautilus_trader.backtest.engine.BacktestEngine object at 0x1452cbb50>>

# %%
# Step 1.5: Load instruments and quote ticks from catalog

import subprocess
import sys

# Get the path to the python executable from the current environment
python_executable = sys.executable

# Define the path to your script
script_path = "0 clean.py"

# Run the script as a separate process
result = subprocess.run(
    [python_executable, script_path],
    capture_output=True,  # Capture stdout and stderr
    text=True,            # Decode output as text
    check=False           # Don't raise an exception on non-zero exit codes
)

# Print the output and any errors
print("--- STDOUT ---")
print(result.stdout)
print("--- STDERR ---")
print(result.stderr)

if result.returncode == 0:
    print(f"\nScript '{script_path}' executed successfully.")
else:
    print(f"\nScript '{script_path}' finished with exit code: {result.returncode}")
# Out:
# --- STDOUT ---
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/.git
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/.git/info
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/.git/hooks
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/.git/refs
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/.git/refs/heads
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/.git/refs/tags
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/.git/refs/remotes
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/.git/refs/remotes/gitrepo
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/.git/objects
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/.git/objects/pack
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/.git/objects/6c
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/.git/objects/info
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/.git/objects/bd
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/.git/objects/b7
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/.git/objects/52
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/.git/objects/99
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/.git/objects/96
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/.git/objects/e8
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/.git/objects/ea
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/.git/objects/88
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/.git/objects/64
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/.git/objects/40
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/.git/objects/93
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/.git/objects/e6
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/.git/objects/f3
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/.git/objects/7b
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/.git/objects/e2
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/.git/objects/b3
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/.git/logs
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/.git/logs/refs
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/.git/logs/refs/heads
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/.git/logs/refs/remotes
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/.git/logs/refs/remotes/gitrepo
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/src
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/src/__pycache__
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/src/strategies
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/src/strategies/__pycache__
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/src/config
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/src/utils
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/src/utils/__pycache__
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/src/backtest
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/src/live
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/data
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/data/nse
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/data/nse/sample
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/.ipynb_checkpoints
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/config
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/.logs
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/Jupyter Code
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/Jupyter Code/.ipynb_checkpoints
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/Jupyter Code/catalog
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/Jupyter Code/catalog-meta
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.40500.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.42000.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.42500.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.43000.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.43500.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.44000.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.44500.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.44900.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.45000.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.45100.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.45200.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.45300.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.45400.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.45500.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.45600.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.45700.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.45800.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.45900.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.46000.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.46100.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.46200.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.46300.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.46400.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.46500.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.46600.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.46700.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.46800.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.46900.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.47000.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.47100.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.47200.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.47300.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.47400.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.47500.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.47600.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.47700.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.47800.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.47900.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.48000.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.48100.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.48200.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.48300.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.48400.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.48500.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.48600.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.48700.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.48800.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.48900.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.49000.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.49100.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.49200.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.49300.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.49400.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.49500.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.49600.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.49700.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.49800.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.49900.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.50000.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.50100.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.50200.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.50300.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.50400.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.50500.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.50600.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.50700.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.50800.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.50900.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.51000.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.51100.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.51200.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.51300.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.51400.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.51500.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.51600.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.51700.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.51800.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.51900.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.52000.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.52100.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.52200.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.52300.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.52400.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.52500.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.52600.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.52700.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.52800.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.52900.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.53000.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.53100.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.53200.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.53300.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.53400.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.53500.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.53600.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.53700.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.53800.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.53900.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.54000.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.54100.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.54200.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.54300.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.54400.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.54500.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.54600.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.54700.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.54800.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.54900.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.55000.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.55100.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.55200.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.55300.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.55400.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.55500.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.55600.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.55700.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.55800.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.55900.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.56000.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.56100.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.56200.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.56300.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.56400.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.56500.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.56600.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.56700.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.56800.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.56900.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.57000.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.57100.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.57200.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.57300.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.57400.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.57500.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.57600.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.57700.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.57800.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.57900.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.58000.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.58100.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.58200.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.58300.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.58400.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.58500.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.58600.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.58700.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.58800.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.58900.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.59000.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.59100.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.59200.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.59300.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.59400.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.59500.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.59600.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.59700.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.59800.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.59900.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.60000.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.60100.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.60200.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.60300.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.60400.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.60500.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.60600.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.60700.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.60800.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.60900.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.61000.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.61100.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.61200.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.61300.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.61400.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.61500.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.61600.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.61700.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.61800.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.62000.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.62500.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.63000.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.63500.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.64000.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/option_contract/BANKNIFTY.OPT.26Jun2025.64500.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.40500.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.42000.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.42500.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.43000.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.43500.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.44000.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.44500.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.44900.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.45000.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.45100.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.45200.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.45300.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.45400.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.45500.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.45600.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.45700.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.45800.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.45900.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.46000.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.46100.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.46200.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.46300.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.46400.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.46500.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.46600.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.46700.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.46800.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.46900.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.47000.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.47100.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.47200.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.47300.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.47400.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.47500.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.47600.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.47700.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.47800.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.47900.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.48000.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.48100.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.48200.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.48300.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.48400.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.48500.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.48600.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.48700.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.48800.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.48900.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.49000.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.49100.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.49200.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.49300.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.49400.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.49500.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.49600.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.49700.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.49800.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.49900.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.50000.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.50100.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.50200.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.50300.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.50400.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.50500.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.50600.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.50700.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.50800.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.50900.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.51000.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.51100.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.51200.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.51300.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.51400.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.51500.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.51600.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.51700.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.51800.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.51900.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.52000.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.52100.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.52200.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.52300.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.52400.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.52500.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.52600.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.52700.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.52800.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.52900.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.53000.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.53100.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.53200.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.53300.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.53400.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.53500.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.53600.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.53700.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.53800.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.53900.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.54000.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.54100.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.54200.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.54300.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.54400.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.54500.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.54600.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.54700.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.54800.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.54900.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.55000.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.55100.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.55200.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.55300.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.55400.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.55500.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.55600.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.55700.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.55800.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.55900.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.56000.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.56100.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.56200.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.56300.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.56400.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.56500.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.56600.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.56700.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.56800.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.56900.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.57000.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.57100.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.57200.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.57300.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.57400.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.57500.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.57600.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.57700.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.57800.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.57900.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.58000.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.58100.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.58200.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.58300.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.58400.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.58500.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.58600.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.58700.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.58800.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.58900.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.59000.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.59100.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.59200.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.59300.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.59400.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.59500.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.59600.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.59700.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.59800.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.59900.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.60000.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.60100.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.60200.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.60300.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.60400.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.60500.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.60600.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.60700.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.60800.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.60900.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.61000.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.61100.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.61200.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.61300.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.61400.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.61500.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.61600.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.61700.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.61800.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.62000.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.62500.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.63000.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.63500.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.64000.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog/data/quote_tick/BANKNIFTY.OPT.26Jun2025.64500.CALL.NSE
# Cleaning: /Volumes/T7/Code Repositories/NTbasedPlatform/catalog-meta
# Deleting all .DS_Store files (except excluded dirs)...
#
# --- STDERR ---
#
#
# Script '0 clean.py' executed successfully.

# %%
# Step 2: Load instruments and quote ticks from catalog
data_catalog = ParquetDataCatalog("catalog")  # folder with .parquet files

# Load all instruments from the catalog
original_instruments = data_catalog.instruments()
print(f"Loaded {len(original_instruments)} original instruments from catalog.")

# **THE FIX**: Iterate through instruments and correct the activation timestamp
corrected_instruments = []
for inst in original_instruments:
    if isinstance(inst, OptionContract):
        # Re-create the OptionContract with activation_ns set to 0
        inst_dict = OptionContract.to_dict(inst)
        inst_dict["activation_ns"] = 0
        corrected_inst = OptionContract.from_dict(inst_dict)
        corrected_instruments.append(corrected_inst)
    else:
        # If not an option contract, just append as-is
        corrected_instruments.append(inst)
print(f"Corrected {len(corrected_instruments)} instruments with activation_ns=0.")

# Use the corrected instruments
instruments = corrected_instruments

# Load all quote ticks from the catalog
ticks = data_catalog.quote_ticks()
print(f"Loaded {len(ticks)} quote ticks from catalog.")
# Out:
# Loaded 183 original instruments from catalog.
# Corrected 183 instruments with activation_ns=0.
# Loaded 1830 quote ticks from catalog.

# %%
#step 2.5
# Debug: Check what instruments are in the data
print("=== INSTRUMENT ANALYSIS ===")
instrument_counts = {}
for tick in ticks:
    inst_id = str(tick.instrument_id)
    if inst_id not in instrument_counts:
        instrument_counts[inst_id] = 0
    instrument_counts[inst_id] += 1

print("Instruments in data:")
for inst_id, count in instrument_counts.items():
    print(f"  - {inst_id}: {count} ticks")

# Check if our target instrument has data
target_inst = "BANKNIFTY.OPT.26Jun2025.64000.CALL.NSE"
if target_inst in instrument_counts:
    print(f"✅ Target instrument {target_inst} has {instrument_counts[target_inst]} ticks")
else:
    print(f"❌ Target instrument {target_inst} has NO ticks!")
    print("Available instruments:")
    for inst_id in instrument_counts.keys():
        if "64000" in inst_id:
            print(f"  - Found similar: {inst_id}")
# Out:
# === INSTRUMENT ANALYSIS ===
# Instruments in data:
#   - BANKNIFTY.OPT.26Jun2025.40500.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.42500.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.44500.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.45600.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.47200.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.50400.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.56800.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.56700.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.50300.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.56600.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.56500.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.47100.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.50200.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.56400.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.56300.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.50100.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.56200.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.56100.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.45500.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.47000.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.50000.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.56000.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.55900.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.49900.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.55800.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.55700.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.46900.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.49800.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.55600.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.55500.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.49700.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.55400.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.55300.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.44000.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.45400.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.46800.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.49600.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.55200.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.55100.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.49500.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.55000.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.54900.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.46700.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.49400.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.54800.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.54700.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.49300.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.54600.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.54500.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.45300.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.46600.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.49200.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.54400.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.54300.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.49100.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.54200.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.54100.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.46500.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.49000.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.54000.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.53900.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.48900.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.53800.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.53700.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.42000.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.43500.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.45200.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.46400.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.48800.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.53600.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.53500.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.48700.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.53400.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.53300.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.46300.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.48600.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.53200.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.64500.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.64000.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.53100.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.63500.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.63000.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.48500.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.53000.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.62500.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.62000.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.52900.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.61800.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.61700.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.45100.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.46200.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.48400.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.52800.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.61600.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.61500.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.52700.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.61400.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.61300.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.48300.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.52600.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.61200.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.61100.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.52500.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.61000.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.60900.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.46100.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.48200.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.52400.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.60800.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.60700.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.52300.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.60600.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.60500.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.48100.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.52200.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.60400.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.60300.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.52100.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.60200.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.60100.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.43000.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.45000.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.46000.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.48000.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.52000.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.60000.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.59900.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.51900.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.59800.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.59700.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.47900.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.51800.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.59600.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.59500.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.51700.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.59400.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.59300.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.45900.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.47800.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.51600.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.59200.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.59100.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.51500.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.59000.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.58900.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.47700.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.51400.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.58800.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.58700.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.51300.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.58600.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.58500.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.44900.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.45800.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.47600.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.51200.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.58400.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.58300.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.51100.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.58200.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.58100.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.47500.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.51000.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.58000.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.57900.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.50900.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.57800.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.57700.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.45700.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.47400.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.50800.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.57600.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.57500.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.50700.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.57400.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.57300.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.47300.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.50600.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.57200.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.57100.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.50500.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.57000.CALL.NSE: 10 ticks
#   - BANKNIFTY.OPT.26Jun2025.56900.CALL.NSE: 10 ticks
# ✅ Target instrument BANKNIFTY.OPT.26Jun2025.64000.CALL.NSE has 10 ticks

# %%
# Step 3: Add venue, instrument, and data to engine
venue_id = "NSE"
existing_venues = [str(v) for v in engine.list_venues()]
print ("Why")
if venue_id not in existing_venues:
    engine.add_venue(
        venue=Venue(venue_id),
        oms_type=OmsType.NETTING,
        account_type=AccountType.MARGIN,
        starting_balances=[Money(1_000_000, INR)],
        base_currency=INR,
        default_leverage=Decimal(1),
    )
# Add all instruments
for inst in instruments:
    try:
        engine.add_instrument(inst)
    except Exception as e:
        print(f"⚠️ Error adding instrument {inst.instrument_id}: {e}")
print("✅ Added instruments to engine.")

# Add all quote ticks (remove the try-except to see any errors)
engine.add_data(ticks)
print(f"✅ Added {len(ticks)} quote ticks to the engine.")
# Out:
# Why
# 2025-06-22T07:08:45.726942000Z [INFO] BACKTEST_TRADER-001.SimulatedExchange(NSE): OmsType=NETTING
# 2025-06-22T07:08:45.728039000Z [INFO] BACKTEST_TRADER-001.ExecClient-NSE: READY
# 2025-06-22T07:08:45.728304000Z [INFO] BACKTEST_TRADER-001.SimulatedExchange(NSE): Registered ExecutionClient-NSE
# 2025-06-22T07:08:45.728342000Z [INFO] BACKTEST_TRADER-001.ExecEngine: Registered ExecutionClient-NSE
# 2025-06-22T07:08:45.730322000Z [INFO] BACKTEST_TRADER-001.DataClient-NSE: READY
# 2025-06-22T07:08:45.730368000Z [INFO] BACKTEST_TRADER-001.DataEngine: Registered NSE
# 2025-06-22T07:08:45.730388000Z [INFO] BACKTEST_TRADER-001.BacktestEngine: Added SimulatedExchange(id=NSE, oms_type=NETTING, account_type=MARGIN)
# 2025-06-22T07:08:45.730960000Z [DEBUG] BACKTEST_TRADER-001.Cache: Added instrument BANKNIFTY.OPT.26Jun2025.40500.CALL.NSE
# 2025-06-22T07:08:45.731874000Z [INFO] BACKTEST_TRADER-001.SimulatedExchange(NSE): Added instrument BANKNIFTY.OPT.26Jun2025.40500.CALL.NSE and created matching engine
# 2025-06-✅ Added instruments to engine.
# ✅ Added 1830 quote ticks to the engine.
# 22T07:08:45.731881000Z [INFO] BACKTEST_TRADER-001.BacktestEngine: Added BANKNIFTY.OPT.26Jun2025.40500.CALL.NSE Instrument
# 2025-06-22T07:08:45.731894000Z [DEBUG] BACKTEST_TRADER-001.Cache: Added instrument BANKNIFTY.OPT.26Jun2025.42000.CALL.NSE
# 2025-06-22T07:08:45.731923000Z [INFO] BACKTEST_TRADER-001.SimulatedExchange(NSE): Added instrument BANKNIFTY.OPT.26Jun2025.42000.CALL.NSE and created matching engine
# 2025-06-22T07:08:45.731927000Z [INFO] BACKTEST_TRADER-001.BacktestEngine: Added BANKNIFTY.OPT.26Jun2025.42000.CALL.NSE Instrument
# 2025-06-22T07:08:45.731934000Z [DEBUG] BACKTEST_TRADER-001.Cache: Added instrument BANKNIFTY.OPT.26Jun2025.42500.CALL.NSE
# 2025-06-22T07:08:45.731954000Z [INFO] BACKTEST_TRADER-001.SimulatedExchange(NSE): Added instrument BANKNIFTY.OPT.26Jun2025.42500.CALL.NSE and created matching engine
# 2025-06-22T07:08:45.731958000Z [INFO] BACKTEST_TRADER-001.BacktestEngine: Added BANKNIFTY.OPT.26Jun2025.42500.CALL.NSE Instrument
# 2025-06-22T07:08:45.731964000Z [DEBUG] BACKTEST_TRADER-001.Cache: Added instrument BANKNIFTY.OPT.26Jun2025.43000.CALL.NSE
# 2025-06-22T07:08:45.731982000Z [INFO] BACKTEST_TRADER-001.SimulatedExchange(NSE): Added instrument BANKNIFTY.OPT.26Jun2025.43000.CALL.NSE and created matching engine
# 2025-06-22T07:08:45.731985000Z [INFO] BACKTEST_TRADER-001.BacktestEngine: Added BANKNIFTY.OPT.26Jun2025.43000.CALL.NSE Instrument
# 2025-06-22T07:08:45.731991000Z [DEBUG] BACKTEST_TRADER-001.Cache: Added instrument BANKNIFTY.OPT.26Jun2025.43500.CALL.NSE
# 2025-06-22T07:08:45.732009000Z [INFO] BACKTEST_TRADER-001.SimulatedExchange(NSE): Added instrument BANKNIFTY.OPT.26Jun2025.43500.CALL.NSE and created matching engine
# 2025-06-22T07:08:45.732012000Z [INFO] BACKTEST_TRADER-001.BacktestEngine: Added BANKNIFTY.OPT.26Jun2025.43500.CALL.NSE Instrument
# 2025-06-22T07:08:45.732019000Z [DEBUG] BACKTEST_TRADER-001.Cache: Added instrument BANKNIFTY.OPT.26Jun2025.44000.CALL.NSE
# 2025-06-22T07:08:45.732036000Z [INFO] BACKTEST_TRADER-001.SimulatedExchange(NSE): Added instrument BANKNIFTY.OPT.26Jun2025.44000.CALL.NSE and created matching engine
# 2025-06-22T07:08:45.732039000Z [INFO] BACKTEST_TRADER-001.BacktestEngine: Added BANKNIFTY.OPT.26Jun2025.44000.CALL.NSE Instrument
# 2025-06-22T07:08:45.732044000Z [DEBUG] BACKTEST_TRADER-001.Cache: Added instrument BANKNIFTY.OPT.26Jun2025.44500.CALL.NSE
# 2025-06-22T07:08:45.732060000Z [INFO] BACKTEST_TRADER-001.SimulatedExchange(NSE): Added instrument BANKNIFTY.OPT.26Jun2025.44500.CALL.NSE and created matching engine
# 2025-06-22T07:08:45.732063000Z [INFO] BACKTEST_TRADER-001.BacktestEngine: Added BANKNIFTY.OPT.26Jun2025.44500.CALL.NSE Instrument
# 2025-06-22T07:08:45.732069000Z [DEBUG] BACKTEST_TRADER-001.Cache: Added instrument BANKNIFTY.OPT.26Jun2025.44900.CALL.NSE
# 2025-06-22T07:08:45.732089000Z [INFO] BACKTEST_TRADER-001.SimulatedExchange(NSE): Added instrument BANKNIFTY.OPT.26Jun2025.44900.CALL.NSE and created matching engine
# 2025-06-22T07:08:45.732092000Z [INFO] BACKTEST_TRADER-001.BacktestEngine: Added BANKNIFTY.OPT.26Jun2025.44900.CALL.NSE Instrument
# 2025-06-22T07:08:45.732097000Z [DEBUG] BACKTEST_TRADER-001.Cache: Added instrument BANKNIFTY.OPT.26Jun2025.45000.CALL.NSE
# 2025-06-22T07:08:45.732113000Z [INFO] BACKTEST_TRADER-001.SimulatedExchange(NSE): Added instrument BANKNIFTY.OPT.26Jun2025.45000.CALL.NSE and created matching engine
# 2025-06-22T07:08:45.732116000Z [INFO] BACKTEST_TRADER-001.BacktestEngine: Added BANKNIFTY.OPT.26Jun2025.45000.CALL.NSE Instrument
# 2025-06-22T07:08:45.732121000Z [DEBUG] BACKTEST_TRADER-001.Cache: Added instrument BANKNIFTY.OPT.26Jun2025.45100.CALL.NSE
# 2025-06-22T07:08:45.732136000Z [INFO] BACKTEST_TRADER-001.SimulatedExchange(NSE): Added instrument BANKNIFTY.OPT.26Jun2025.45100.CALL.NSE and created matching engine
# 2025-06-22T07:08:45.732139000Z [INFO] BACKTEST_TRADER-001.BacktestEngine: Added BANKNIFTY.OPT.26Jun2025.45100.CALL.NSE Instrument
# 2025-06-22T07:08:45.732144000Z [DEBUG] BACKTEST_TRADER-001.Cache: Added instrument BANKNIFTY.OPT.26Jun2025.45200.CALL.NSE
# 2025-06-22T07:08:45.732160000Z [INFO] BACKTEST_TRADER-001.SimulatedExchange(NSE): Added instrument BANKNIFTY.OPT.26Jun2025.45200.CALL.NSE and created matching engine
# 2025-06-22T07:08:45.732163000Z [INFO] BACKTEST_TRADER-001.BacktestEngine: Added BANKNIFTY.OPT.26Jun2025.45200.CALL.NSE Instrument
# 2025-06-22T07:08:45.732168000Z [DEBUG] BACKTEST_TRADER-001.Cache: Added instrument BANKNIFTY.OPT.26Jun2025.45300.CALL.NSE
# 2025-06-22T07:08:45.732189000Z [INFO] BACKTEST_TRADER-001.SimulatedExchange(NSE): Added instrument BANKNIFTY.OPT.26Jun2025.45300.CALL.NSE and created matching engine
# 2025-06-22T07:08:45.732192000Z [INFO] BACKTEST_TRADER-001.BacktestEngine: Added BANKNIFTY.OPT.26Jun2025.45300.CALL.NSE Instrument
# 2025-06-22T07:08:45.732197000Z [DEBUG] BACKTEST_TRADER-001.Cache: Added instrument BANKNIFTY.OPT.26Jun2025.45400.CALL.NSE
# 2025-06-22T07:08:45.732213000Z [INFO] BACKTEST_TRADER-001.SimulatedExchange(NSE): Added instrument BANKNIFTY.OPT.26Jun2025.45400.CALL.NSE and created matching engine
# 2025-06-22T07:08:45.732216000Z [INFO] BACKTEST_TRADER-001.BacktestEngine: Added BANKNIFTY.OPT.26Jun2025.45400.CALL.NSE Instrument
# 2025-06-22T07:08:45.732221000Z [DEBUG] BACKTEST_TRADER-001.Cache: Added instrument BANKNIFTY.OPT.26Jun2025.45500.CALL.NSE
# 2025-06-22T07:08:45.732241000Z [INFO] BACKTEST_TRADER-001.SimulatedExchange(NSE): Added instrument BANKNIFTY.OPT.26Jun2025.45500.CALL.NSE and created matching engine
# 2025-06-22T07:08:45.732244000Z [INFO] BACKTEST_TRADER-001.BacktestEngine: Added BANKNIFTY.OPT.26Jun2025.45500.CALL.NSE Instrument
# 2025-06-22T07:08:45.732249000Z [DEBUG] BACKTEST_TRADER-001.Cache: Added instrument BANKNIFTY.OPT.26Jun2025.45600.CALL.NSE
# 2025-06-22T07:08:45.732265000Z [INFO] BACKTEST_TRADER-001.SimulatedExchange(NSE): Added instrument BANKNIFTY.OPT.26Jun2025.45600.CALL.NSE and created matching engine
# 2025-06-22T07:08:45.732268000Z [INFO] BACKTEST_TRADER-001.BacktestEngine: Added BANKNIFTY.OPT.26Jun2025.45600.CALL.NSE Instrument
# 2025-06-22T07:08:45.732273000Z [DEBUG] BACKTEST_TRADER-001.Cache: Added instrument BANKNIFTY.OPT.26Jun2025.45700.CALL.NSE
# 2025-06-22T07:08:45.732289000Z [INFO] BACKTEST_TRADER-001.SimulatedExchange(NSE): Added instrument BANKNIFTY.OPT.26Jun2025.45700.CALL.NSE and created matching engine
# 2025-06-22T07:08:45.732292000Z [INFO] BACKTEST_TRADER-001.BacktestEngine: Added BANKNIFTY.OPT.26Jun2025.
Z [DEBUG] BACKTEST_TRADER-001.Cache: Added instrument BANKNIFTY.OPT.26Jun2025.64000.CALL.NSE
# 2025-06-22T07:08:45.735653000Z [INFO] BACKTEST_TRADER-001.SimulatedExchange(NSE): Added instrument BANKNIFTY.OPT.26Jun2025.64000.CALL.NSE and created matching engine
# 2025-06-22T07:08:45.735653001Z [INFO] BACKTEST_TRADER-001.BacktestEngine: Added BANKNIFTY.OPT.26Jun2025.64000.CALL.NSE Instrument
# 2025-06-22T07:08:45.735655000Z [DEBUG] BACKTEST_TRADER-001.Cache: Added instrument BANKNIFTY.OPT.26Jun2025.64500.CALL.NSE
# 2025-06-22T07:08:45.735660000Z [INFO] BACKTEST_TRADER-001.SimulatedExchange(NSE): Added instrument BANKNIFTY.OPT.26Jun2025.64500.CALL.NSE and created matching engine
# 2025-06-22T07:08:45.735661000Z [INFO] BACKTEST_TRADER-001.BacktestEngine: Added BANKNIFTY.OPT.26Jun2025.64500.CALL.NSE Instrument
# 2025-06-22T07:08:45.736783000Z [INFO] BACKTEST_TRADER-001.BacktestEngine: Added 1_830 BANKNIFTY.OPT.26Jun2025.40500.CALL.NSE QuoteTick elements

# %%
# Fix instrument activation timestamps
corrected_instruments = []
for inst in instruments:
    if hasattr(inst, 'activation_ns'):
        inst_dict = OptionContract.to_dict(inst)
        inst_dict['activation_ns'] = 0
        corrected_inst = OptionContract.from_dict(inst_dict)
        corrected_instruments.append(corrected_inst)
    else:
        corrected_instruments.append(inst)

# Replace the original instruments with corrected ones
instruments = corrected_instruments

# %%
# Step 3.5
# Debug: Check if target instrument and ticks exist
target_instrument_id = InstrumentId.from_str("BANKNIFTY.OPT.26Jun2025.64000.CALL.NSE")

# Check instruments
target_instrument = None
for inst in instruments:
    if inst.id == target_instrument_id:  # Changed from inst.instrument_id to inst.id
        target_instrument = inst
        break
print(f"Target instrument found: {target_instrument is not None}")

# Check ticks
target_ticks = [t for t in ticks if t.instrument_id == target_instrument_id]
print(f"Ticks for target instrument: {len(target_ticks)}")

if len(target_ticks) > 0:
    print(f"First tick: {target_ticks[0]}")
    print(f"Last tick: {target_ticks[-1]}")
else:
    print("❌ NO TICKS FOUND FOR TARGET INSTRUMENT!")
# Out:
# Target instrument found: True
# Ticks for target instrument: 10
# First tick: BANKNIFTY.OPT.26Jun2025.64000.CALL.NSE,376.00,396.00,1,1,1750248000000000000
# Last tick: BANKNIFTY.OPT.26Jun2025.64000.CALL.NSE,374.00,395.00,1,1,1750256100000000000

# %%
# Step 4: Add your strategy
import sys
sys.path.append('src')
import yaml
from strategies.my_nse_strategy import MyNSEStrategy, MyNSEStrategyConfig
from nautilus_trader.model import InstrumentId

# Load YAML
with open("src/config/nse_strategy_config.yaml") as f:
    yaml_config = yaml.safe_load(f)

# Create config with just the essential parameters
config = MyNSEStrategyConfig(
    instrument_id=InstrumentId.from_str("BANKNIFTY.OPT.26Jun2025.64000.CALL.NSE"),
    # All other parameters will use their default values from the class
)
strategy = MyNSEStrategy(config)

# Debug: Check strategy before adding
print(f"Strategy ID: {strategy.id}")
print(f"Strategy state: {strategy.state}")
print(f"Strategy config: {strategy.config}")

# Add strategy to engine
engine.add_strategy(strategy)

# Debug: Check if strategy was added
print(f"Strategy added to engine")
print(f"Engine trader ID: {engine.trader_id}")
# Out:
# 2025-06-22T07:08:51.041477000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: Loading metadata from 1 file(s)...
# Strategy ID: MyNSEStrategy-None
# Strategy state: 0
# Strategy config: MyNSEStrategyConfig(instrument_id=InstrumentId('BANKNIFTY.OPT.26Jun2025.64000.CALL.NSE'), meta_catalog_path='catalog-meta', sl_pct=0.02, tp_pct=0.03, position_size=1, end_time='15:15', min_iv=0, entry_buffer_pct=0.01, lookback_intervals=2, min_oi_change=-100, breakeven_trigger_pct=2, sar_enabled=True, strategy_id=None, order_id_tag=None, use_uuid_client_order_ids=False, oms_type=None, external_order_claims=None, manage_contingent_orders=False, manage_gtd_expiry=False, log_events=True, log_commands=True)
# Strategy added to engine
# Engine trader ID: BACKTEST_TRADER-001
# 2025-06-22T07:08:51.070740000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: Loaded 1830 metadata records.
# 2025-06-22T07:08:51.071626000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: READY
# 2025-06-22T07:08:51.071735000Z [DEBUG] BACKTEST_TRADER-001.MessageBus: Added Subscription(topic=events.order.MyNSEStrategy-000, handler=<bound method Strategy.handle_event of MyNSEStrategy(MyNSEStrategy-000)>, priority=0)
# 2025-06-22T07:08:51.071752000Z [DEBUG] BACKTEST_TRADER-001.MessageBus: Added Subscription(topic=events.position.MyNSEStrategy-000, handler=<bound method Strategy.handle_event of MyNSEStrategy(MyNSEStrategy-000)>, priority=0)
# 2025-06-22T07:08:51.071769000Z [INFO] BACKTEST_TRADER-001.ExecEngine: Registered OMS.UNSPECIFIED for Strategy MyNSEStrategy-000
# 2025-06-22T07:08:51.071777000Z [INFO] BACKTEST_TRADER-001.BACKTEST_TRADER-001: Registered Strategy MyNSEStrategy-000

# %%
# Step 4.5
# Debug: Check strategy setup
print("=== STRATEGY DEBUGGING ===")
print(f"Strategy ID: {strategy.id}")
print(f"Strategy instrument: {strategy.config.instrument_id}")

# Check if strategy is properly configured
print(f"Strategy has on_start method: {hasattr(strategy, 'on_start')}")
print(f"Strategy has subscribe_quote_ticks method: {hasattr(strategy, 'subscribe_quote_ticks')}")

# Check engine state (using correct methods)
print(f"Engine trader ID: {engine.trader_id}")

# Check if data was added successfully
print(f"Total instruments we loaded: {len(instruments)}")
print(f"Total ticks we loaded: {len(ticks)}")

# Check strategy configuration
print(f"Strategy config instrument: {strategy.config.instrument_id}")
print(f"Target instrument ID: {target_instrument_id}")
print(f"Strategy and target match: {strategy.config.instrument_id == target_instrument_id}")
# Out:
# === STRATEGY DEBUGGING ===
# Strategy ID: MyNSEStrategy-000
# Strategy instrument: BANKNIFTY.OPT.26Jun2025.64000.CALL.NSE
# Strategy has on_start method: True
# Strategy has subscribe_quote_ticks method: True
# Engine trader ID: BACKTEST_TRADER-001
# Total instruments we loaded: 183
# Total ticks we loaded: 1830
# Strategy config instrument: BANKNIFTY.OPT.26Jun2025.64000.CALL.NSE
# Target instrument ID: BANKNIFTY.OPT.26Jun2025.64000.CALL.NSE
# Strategy and target match: True

# %%
# Debug: Check engine and strategy state before running
print("=== PRE-RUN DEBUGGING ===")
print(f"Engine trader ID: {engine.trader_id}")
print(f"Strategy state: {strategy.state}")
print(f"Strategy ID: {strategy.id}")

# Check if strategy is properly registered
print(f"Strategy is registered: {hasattr(strategy, 'trader_id')}")
if hasattr(strategy, 'trader_id'):
    print(f"Strategy trader ID: {strategy.trader_id}")

# Check if strategy has the required components
print(f"Strategy has cache: {hasattr(strategy, 'cache')}")
print(f"Strategy has portfolio: {hasattr(strategy, 'portfolio')}")
print(f"Strategy has order_factory: {hasattr(strategy, 'order_factory')}")
# Out:
# === PRE-RUN DEBUGGING ===
# Engine trader ID: BACKTEST_TRADER-001
# Strategy state: 1
# Strategy ID: MyNSEStrategy-000
# Strategy is registered: True
# Strategy trader ID: BACKTEST_TRADER-001
# Strategy has cache: True
# Strategy has portfolio: True
# Strategy has order_factory: True

# %%
# Add debugging before running
print("=== PRE-RUN DEBUGGING ===")
print(f"Engine trader ID: {engine.trader_id}")
print(f"Strategy state: {strategy.state}")
print(f"Strategy ID: {strategy.id}")
print(f"Strategy trader ID: {strategy.trader_id}")
print(f"Strategy has cache: {strategy.cache is not None}")
print(f"Strategy has portfolio: {strategy.portfolio is not None}")
print(f"Strategy has order_factory: {strategy.order_factory is not None}")

# Check if strategy is subscribed to data
print(f"Strategy subscribed instruments: {list(strategy.subscribed_instruments()) if hasattr(strategy, 'subscribed_instruments') else 'No subscribed_instruments method'}")

# Try to explicitly start the strategy
print("\n=== EXPLICITLY STARTING STRATEGY ===")
try:
    strategy.start()
    print("Strategy started successfully")
except Exception as e:
    print(f"Error starting strategy: {e}")

print(f"Strategy state after start: {strategy.state}")

# Run the backtest
print("\n=== RUNNING BACKTEST ===")
engine.run()

print("\n=== POST-RUN DEBUGGING ===")
print(f"Engine trader ID: {engine.trader_id}")
print(f"Strategy state: {strategy.state}")
print(f"Strategy ID: {strategy.id}")
print(f"Strategy trader ID: {strategy.trader_id}")
print(f"Strategy has cache: {strategy.cache is not None}")
print(f"Strategy has portfolio: {strategy.portfolio is not None}")
print(f"Strategy has order_factory: {strategy.order_factory is not None}")

# Check if strategy received any data
print(f"\nStrategy received quote ticks: {hasattr(strategy, '_quote_tick_count') and strategy._quote_tick_count > 0}")
if hasattr(strategy, '_quote_tick_count'):
    print(f"Quote tick count: {strategy._quote_tick_count}")

# Check engine results
print(f"\nEngine events count: {len(engine.event_log)}")
print(f"Engine orders count: {len(engine.order_log)}")
print(f"Engine positions count: {len(engine.position_log)}")

# Check if strategy has any orders or positions
print(f"\nStrategy orders: {len(strategy.cache.orders()) if strategy.cache else 0}")
print(f"Strategy positions: {len(strategy.cache.positions()) if strategy.cache else 0}")
# Out:
# === PRE-RUN DEBUGGING ===
# Engine trader ID: BACKTEST_TRADER-001
# Strategy state: 1
# Strategy ID: MyNSEStrategy-000
# Strategy trader ID: BACKTEST_TRADER-001
# Strategy has cache: True
# Strategy has portfolio: True
# Strategy has order_factory: True
# Strategy subscribed instruments: No subscribed_instruments method
#
# === EXPLICITLY STARTING STRATEGY ===
# 2025-06-22T07:08:56.566824000Z [DEBUG] BACKTEST_TRADER-001.MyNSEStrategy: STARTING
# 2025-06-22T07:08:56.566845000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: self.config.oms_type=None
# 2025-06-22T07:08:56.566847000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: self.config.external_order_claims=None
# 2025-06-22T07:08:56.566848000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: self.config.manage_gtd_expiry=False
# Strategy started successfully
# Strategy state after start: 3
#
# === RUNNING BACKTEST ===
# 2025-06-22T07:08:56.566883000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: Set ClientOrderIdGenerator client_order_id count to 0
# 2025-06-22T07:08:56.566888000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: Set ClientOrderIdGenerator order_list_id count to 0
# 2025-06-22T07:08:56.566895000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: === STRATEGY ON_START CALLED ===
# 2025-06-22T07:08:56.570504000Z [DEBUG] BACKTEST_TRADER-001.MessageBus: Added Subscription(topic=data.quotes.NSE.BANKNIFTY*, handler=<bound method Actor.handle_quote_tick of MyNSEStrategy(MyNSEStrategy-000)>, priority=0)
# 2025-06-22T07:08:56.571596000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: [CMD]--> SubscribeQuoteTicks(instrument_id=BANKNIFTY.OPT.26Jun2025.64000.CALL.NSE, client_id=None, venue=NSE)
# 2025-06-22T07:08:56.575611000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: Strategy started for instrument: BANKNIFTY.OPT.26Jun2025.64000.CALL.NSE
# 2025-06-22T07:08:56.575615000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: === STRATEGY ON_START COMPLETED ===
# 2025-06-22T07:08:56.575755000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: RUNNING
# 2025-06-22T07:08:56.576336000Z [DEBUG] BACKTEST_TRADER-001.Cache: Added Account(id=NSE-001)
# 2025-06-22T07:08:56.576341000Z [DEBUG] BACKTEST_TRADER-001.Cache: Indexed AccountId('NSE-001')
# 2025-06-22T07:08:56.576382000Z [INFO] BACKTEST_TRADER-001.Portfolio: Updated AccountState(account_id=NSE-001, account_type=MARGIN, base_currency=INR, is_reported=True, balances=[AccountBalance(total=1_000_000.00 INR, locked=0.00 INR, free=1_000_000.00 INR)], margins=[], event_id=f03c1332-5ad0-467c-80de-ed24c9febb56)
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.BacktestEngine: STARTING
# 2025-06-18T12:00:00.000000000Z [DEBUG] BACKTEST_TRADER-001.DataEngine: STARTING
# 2025-06-18T12:00:00.000000000Z [DEBUG] BACKTEST_TRADER-001.DataClient-NSE: STARTING
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.DataClient-NSE: Connecting...
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.DataClient-NSE: Connected
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.DataClient-NSE: RUNNING
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.DataEngine: RUNNING
# 2025-06-18T12:00:00.000000000Z [DEBUG] BACKTEST_TRADER-001.RiskEngine: STARTING
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.RiskEngine: RUNNING
# 2025-06-18T12:00:00.000000000Z [DEBUG] BACKTEST_TRADER-001.ExecEngine: STARTING
# 2025-06-18T12:00:00.000000000Z [DEBUG] BACKTEST_TRADER-001.ExecClient-NSE: STARTING
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.ExecClient-NSE: Connecting...
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.ExecClient-NSE: Connected
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.ExecClient-NSE: RUNNING
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.ExecEngine: RUNNING
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.DataEngine: Connecting all clients...
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.ExecEngine: Connecting all clients...
# 2025-06-18T12:00:00.000000000Z [DEBUG] BACKTEST_TRADER-001.OrderEmulator: STARTING
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.OrderEmulator: No emulated orders to reactivate
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.OrderEmulator: RUNNING
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.Portfolio: Initialized 0 open orders
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.Portfolio: Initialized 0 open positions
# 2025-06-18T12:00:00.000000000Z [DEBUG] BACKTEST_TRADER-001.BACKTEST_TRADER-001: STARTING
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.BACKTEST_TRADER-001: RUNNING
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.BacktestEngine: =================================================================
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.BacktestEngine:  MEMORY USAGE
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.BacktestEngine: =================================================================
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.BacktestEngine: RAM-Total: 16.00 GiB
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.BacktestEngine: RAM-Used: 12.88 GiB (80.47%)
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.BacktestEngine: RAM-Avail: 3.12 GiB (19.53%)
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.BacktestEngine: Swap-Total: 20.00 GiB
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.BacktestEngine: Swap-Used: 18.89 GiB (94.44%)
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.BacktestEngine: Swap-Avail: 1.11 GiB (5.56%)
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.BacktestEngine: =================================================================
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.BacktestEngine:  SimulatedVenue NSE
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.BacktestEngine: =================================================================
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.BacktestEngine: MarginAccount(id=NSE-001, type=MARGIN, base=INR)
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.BacktestEngine: -----------------------------------------------------------------
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.BacktestEngine: Balances starting:
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.BacktestEngine: 1_000_000.00 INR
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.BacktestEngine: =================================================================
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.BacktestEngine:  BACKTEST RUN
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.BacktestEngine: =================================================================
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.BacktestEngine: Run config ID:  None
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.BacktestEngine: Run ID:         9152d9d9-89dd-4c4c-a52f-7fbf1e091a3d
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.BacktestEngine: Run started:    2025-06-22T07:08:56.576173000Z
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.BacktestEngine: Backtest start: 2025-06-18T12:00:00.000000000Z
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.BacktestEngine: Batch start:    2025-06-18T12:00:00.000000000Z
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.BacktestEngine: Batch end:      2025-06-18T14:15:00.000000000Z
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.BacktestEngine: -----------------------------------------------------------------
# 2025-06-18T12:00:00.000000000Z [DEBUG] BACKTEST_TRADER-001.OrderMatchingEngine(NSE): Processing QuoteTick(BANKNIFTY.OPT.26Jun2025.40500.CALL.NSE,1519815.00,1562036.00,1,1,1750248000000000000)
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: === RECEIVED QUOTE TICK: BANKNIFTY.OPT.26Jun2025.40500.CALL.NSE,1519815.00,1562036.00,1,1,1750248000000000000 ===
# 2025-06-18T12:00:00.000000000Z [DEBUG] BACKTEST_TRADER-001.OrderMatchingEngine(NSE): Processing QuoteTick(BANKNIFTY.OPT.26Jun2025.42500.CALL.NSE,1264538.00,1379554.00,1,1,1750248000000000000)
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: === RECEIVED QUOTE TICK: BANKNIFTY.OPT.26Jun2025.42500.CALL.NSE,1264538.00,1379554.00,1,1,1750248000000000000 ===
# 2025-06-18T12:00:00.000000000Z [DEBUG] BACKTEST_TRADER-001.OrderMatchingEngine(NSE): Processing QuoteTick(BANKNIFTY.OPT.26Jun2025.44500.CALL.NSE,1076704.00,1166189.00,1,1,1750248000000000000)
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: === RECEIVED QUOTE TICK: BANKNIFTY.OPT.26Jun2025.44500.CALL.NSE,1076704.00,1166189.00,1,1,1750248000000000000 ===
# 2025-06-18T12:00:00.000000000Z [DEBUG] BACKTEST_TRADER-001.OrderMatchingEngine(NSE): Processing QuoteTick(BANKNIFTY.OPT.26Jun2025.45600.CALL.NSE,994560.00,1045458.00,1,1,1750248000000000000)
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: === RECEIVED QUOTE TICK: BANKNIFTY.OPT.26Jun2025.45600.CALL.NSE,994560.00,1045458.00,1,1,1750248000000000000 ===
# 2025-06-18T12:00:00.000000000Z [DEBUG] BACKTEST_TRADER-001.OrderMatchingEngine(NSE): Processing QuoteTick(BANKNIFTY.OPT.26Jun2025.47200.CALL.NSE,831960.00,890296.00,1,1,1750248000000000000)
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: === RECEIVED QUOTE TICK: BANKNIFTY.OPT.26Jun2025.47200.CALL.NSE,831960.00,890296.00,1,1,1750248000000000000 ===
# 2025-06-18T12:00:00.000000000Z [DEBUG] BACKTEST_TRADER-001.OrderMatchingEngine(NSE): Processing QuoteTick(BANKNIFTY.OPT.26Jun2025.50400.CALL.NSE,528250.00,572064.00,1,1,1750248000000000000)
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: === RECEIVED QUOTE TICK: BANKNIFTY.OPT.26Jun2025.50400.CALL.NSE,528250.00,572064.00,1,1,1750248000000000000 ===
# 2025-06-18T12:00:00.000000000Z [DEBUG] BACKTEST_TRADER-001.OrderMatchingEngine(NSE): Processing QuoteTick(BANKNIFTY.OPT.26Jun2025.56800.CALL.NSE,15489.00,15679.00,1,1,1750248000000000000)
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: === RECEIVED QUOTE TICK: BANKNIFTY.OPT.26Jun2025.56800.CALL.NSE,15489.00,15679.00,1,1,1750248000000000000 ===
# 2025-06-18T12:00:00.000000000Z [DEBUG] BACKTEST_TRADER-001.OrderMatchingEngine(NSE): Processing QuoteTick(BANKNIFTY.OPT.26Jun2025.56700.CALL.NSE,17880.00,17995.00,1,1,1750248000000000000)
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: === RECEIVED QUOTE TICK: BANKNIFTY.OPT.26Jun2025.56700.CALL.NSE,17880.00,17995.00,1,1,1750248000000000000 ===
# 2025-06-18T12:00:00.000000000Z [DEBUG] BACKTEST_TRADER-001.OrderMatchingEngine(NSE): Processing QuoteTick(BANKNIFTY.OPT.26Jun2025.50300.CALL.NSE,546140.00,569145.00,1,1,1750248000000000000)
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: === RECEIVED QUOTE TICK: BANKNIFTY.OPT.26Jun2025.50300.CALL.NSE,546140.00,569145.00,1,1,1750248000000000000 ===
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: *** ENTRY TRIGGERED! *** Price: 557642.50, IV: 21.4856, OI: 0
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: <--[EVT] OrderInitialized(instrument_id=BANKNIFTY.OPT.26Jun2025.64000.CALL.NSE, client_order_id=O-20250618-120000-001-000-1, side=BUY, type=MARKET, quantity=1, time_in_force=DAY, post_only=False, reduce_only=False, quote_quantity=False, options={}, emulation_trigger=NO_TRIGGER, trigger_instrument_id=None, contingency_type=NO_CONTINGENCY, order_list_id=None, linked_order_ids=None, parent_order_id=None, exec_algorithm_id=None, exec_algorithm_params=None, exec_spawn_id=None, tags=['entry-long-0'])
# 2025-06-18T12:00:00.000000000Z [DEBUG] BACKTEST_TRADER-001.Cache: Added MarketOrder(BUY 1 BANKNIFTY.OPT.26Jun2025.64000.CALL.NSE MARKET DAY, status=INITIALIZED, client_order_id=O-20250618-120000-001-000-1, venue_order_id=None, position_id=None, tags=['entry-long-0'])
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: [CMD]--> [Risk] SubmitOrder(order=MarketOrder(BUY 1 BANKNIFTY.OPT.26Jun2025.64000.CALL.NSE MARKET DAY, status=INITIALIZED, client_order_id=O-20250618-120000-001-000-1, venue_order_id=None, position_id=None, tags=['entry-long-0']), position_id=None)
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: <--[EVT] OrderSubmitted(instrument_id=BANKNIFTY.OPT.26Jun2025.64000.CALL.NSE, client_order_id=O-20250618-120000-001-000-1, account_id=NSE-001, ts_event=1750248000000000000)
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: Market order submitted successfully: MarketOrder(BUY 1 BANKNIFTY.OPT.26Jun2025.64000.CALL.NSE MARKET DAY, status=SUBMITTED, client_order_id=O-20250618-120000-001-000-1, venue_order_id=None, position_id=None, tags=['entry-long-0'])
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: Trade parameters set - Entry: 557642.50, SL: 15584.00, TP: 557809.79
# 2025-06-18T12:00:00.000000000Z [WARN] BACKTEST_TRADER-001.MyNSEStrategy: <--[EVT] OrderRejected(instrument_id=BANKNIFTY.OPT.26Jun2025.64000.CALL.NSE, client_order_id=O-20250618-120000-001-000-1, account_id=NSE-001, reason='no market for BANKNIFTY.OPT.26Jun2025.64000.CALL.NSE', ts_event=1750248000000000000)
# 2025-06-18T12:00:00.000000000Z [DEBUG] BACKTEST_TRADER-001.OrderMatchingEngine(NSE): Processing QuoteTick(BANKNIFTY.OPT.26Jun2025.56600.CALL.NSE,20370.00,20506.00,1,1,1750248000000000000)
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: === RECEIVED QUOTE TICK: BANKNIFTY.OPT.26Jun2025.56600.CALL.NSE,20370.00,20506.00,1,1,1750248000000000000 ===
# 2025-06-18T12:00:00.000000000Z [DEBUG] BACKTEST_TRADER-001.OrderMatchingEngine(NSE): Processing QuoteTick(BANKNIFTY.OPT.26Jun2025.56500.CALL.NSE,23150.00,23032.00,1,1,1750248000000000000)
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: === RECEIVED QUOTE TICK: BANKNIFTY.OPT.26Jun2025.56500.CALL.NSE,23150.00,23032.00,1,1,1750248000000000000 ===
# 2025-06-18T12:00:00.000000000Z [DEBUG] BACKTEST_TRADER-001.OrderMatchingEngine(NSE): Processing QuoteTick(BANKNIFTY.OPT.26Jun2025.47100.CALL.NSE,854156.00,909512.00,1,1,1750248000000000000)
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: === RECEIVED QUOTE TICK: BANKNIFTY.OPT.26Jun2025.47100.CALL.NSE,854156.00,909512.00,1,1,1750248000000000000 ===
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: *** ENTRY TRIGGERED! *** Price: 881834.00, IV: 25.8090, OI: 0
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: <--[EVT] OrderInitialized(instrument_id=BANKNIFTY.OPT.26Jun2025.64000.CALL.NSE, client_order_id=O-20250618-120000-001-000-2, side=BUY, type=MARKET, quantity=1, time_in_force=DAY, post_only=False, reduce_only=False, quote_quantity=False, options={}, emulation_trigger=NO_TRIGGER, trigger_instrument_id=None, contingency_type=NO_CONTINGENCY, order_list_id=None, linked_order_ids=None, parent_order_id=None, exec_algorithm_id=None, exec_algorithm_params=None, exec_spawn_id=None, tags=['entry-long-1'])
# 2025-06-18T12:00:00.000000000Z [DEBUG] BACKTEST_TRADER-001.Cache: Added MarketOrder(BUY 1 BANKNIFTY.OPT.26Jun2025.64000.CALL.NSE MARKET DAY, status=INITIALIZED, client_order_id=O-20250618-120000-001-000-2, venue_order_id=None, position_id=None, tags=['entry-long-1'])
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: [CMD]--> [Risk] SubmitOrder(order=MarketOrder(BUY 1 BANKNIFTY.OPT.26Jun2025.64000.CALL.NSE MARKET DAY, status=INITIALIZED, client_order_id=O-20250618-120000-001-000-2, venue_order_id=None, position_id=None, tags=['entry-long-1']), position_id=None)
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: <--[EVT] OrderSubmitted(instrument_id=BANKNIFTY.OPT.26Jun2025.64000.CALL.NSE, client_order_id=O-20250618-120000-001-000-2, account_id=NSE-001, ts_event=1750248000000000000)
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: Market order submitted successfully: MarketOrder(BUY 1 BANKNIFTY.OPT.26Jun2025.64000.CALL.NSE MARKET DAY, status=SUBMITTED, client_order_id=O-20250618-120000-001-000-2, venue_order_id=None, position_id=None, tags=['entry-long-1'])
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: Trade parameters set - Entry: 881834.00, SL: 20438.00, TP: 882098.55
# 2025-06-18T12:00:00.000000000Z [WARN] BACKTEST_TRADER-001.MyNSEStrategy: <--[EVT] OrderRejected(instrument_id=BANKNIFTY.OPT.26Jun2025.64000.CALL.NSE, client_order_id=O-20250618-120000-001-000-2, account_id=NSE-001, reason='no market for BANKNIFTY.OPT.26Jun2025.64000.CALL.NSE', ts_event=1750248000000000000)
# 2025-06-18T12:00:00.000000000Z [DEBUG] BACKTEST_TRADER-001.OrderMatchingEngine(NSE): Processing QuoteTick(BANKNIFTY.OPT.26Jun2025.50200.CALL.NSE,553994.00,585001.00,1,1,1750248000000000000)
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: === RECEIVED QUOTE TICK: BANKNIFTY.OPT.26Jun2025.50200.CALL.NSE,553994.00,585001.00,1,1,1750248000000000000 ===
# 2025-06-18T12:00:00.000000000Z [DEBUG] BACKTEST_TRADER-001.OrderMatchingEngine(NSE): Processing QuoteTick(BANKNIFTY.OPT.26Jun2025.56400.CALL.NSE,26262.00,25971.00,1,1,1750248000000000000)
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: === RECEIVED QUOTE TICK: BANKNIFTY.OPT.26Jun2025.56400.CALL.NSE,26262.00,25971.00,1,1,1750248000000000000 ===
# 2025-06-18T12:00:00.000000000Z [DEBUG] BACKTEST_TRADER-001.OrderMatchingEngine(NSE): Processing QuoteTick(BANKNIFTY.OPT.26Jun2025.56300.CALL.NSE,29457.00,30470.00,1,1,1750248000000000000)
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: === RECEIVED QUOTE TICK: BANKNIFTY.OPT.26Jun2025.56300.CALL.NSE,29457.00,30470.00,1,1,1750248000000000000 ===
# 2025-06-18T12:00:00.000000000Z [DEBUG] BACKTEST_TRADER-001.OrderMatchingEngine(NSE): Processing QuoteTick(BANKNIFTY.OPT.26Jun2025.50100.CALL.NSE,573760.00,590216.00,1,1,1750248000000000000)
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: === RECEIVED QUOTE TICK: BANKNIFTY.OPT.26Jun2025.50100.CALL.NSE,573760.00,590216.00,1,1,1750248000000000000 ===
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: *** ENTRY TRIGGERED! *** Price: 581988.00, IV: 33.2197, OI: 0
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: <--[EVT] OrderInitialized(instrument_id=BANKNIFTY.OPT.26Jun2025.64000.CALL.NSE, client_order_id=O-20250618-120000-001-000-3, si
# === POST-RUN DEBUGGING ===
# Engine trader ID: BACKTEST_TRADER-001
# Strategy state: 5
# Strategy ID: MyNSEStrategy-000
# Strategy trader ID: BACKTEST_TRADER-001
# Strategy has cache: True
# Strategy has portfolio: True
# Strategy has order_factory: True
#
# Strategy received quote ticks: False
# de=BUY, type=MARKET, quantity=1, time_in_force=DAY, post_only=False, reduce_only=False, quote_quantity=False, options={}, emulation_trigger=NO_TRIGGER, trigger_instrument_id=None, contingency_type=NO_CONTINGENCY, order_list_id=None, linked_order_ids=None, parent_order_id=None, exec_algorithm_id=None, exec_algorithm_params=None, exec_spawn_id=None, tags=['entry-long-2'])
# 2025-06-18T12:00:00.000000000Z [DEBUG] BACKTEST_TRADER-001.Cache: Added MarketOrder(BUY 1 BANKNIFTY.OPT.26Jun2025.64000.CALL.NSE MARKET DAY, status=INITIALIZED, client_order_id=O-20250618-120000-001-000-3, venue_order_id=None, position_id=None, tags=['entry-long-2'])
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: [CMD]--> [Risk] SubmitOrder(order=MarketOrder(BUY 1 BANKNIFTY.OPT.26Jun2025.64000.CALL.NSE MARKET DAY, status=INITIALIZED, client_order_id=O-20250618-120000-001-000-3, venue_order_id=None, position_id=None, tags=['entry-long-2']), position_id=None)
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: <--[EVT] OrderSubmitted(instrument_id=BANKNIFTY.OPT.26Jun2025.64000.CALL.NSE, client_order_id=O-20250618-120000-001-000-3, account_id=NSE-001, ts_event=1750248000000000000)
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: Market order submitted successfully: MarketOrder(BUY 1 BANKNIFTY.OPT.26Jun2025.64000.CALL.NSE MARKET DAY, status=SUBMITTED, client_order_id=O-20250618-120000-001-000-3, venue_order_id=None, position_id=None, tags=['entry-long-2'])
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: Trade parameters set - Entry: 581988.00, SL: 26116.50, TP: 582162.60
# 2025-06-18T12:00:00.000000000Z [WARN] BACKTEST_TRADER-001.MyNSEStrategy: <--[EVT] OrderRejected(instrument_id=BANKNIFTY.OPT.26Jun2025.64000.CALL.NSE, client_order_id=O-20250618-120000-001-000-3, account_id=NSE-001, reason='no market for BANKNIFTY.OPT.26Jun2025.64000.CALL.NSE', ts_event=1750248000000000000)
# 2025-06-18T12:00:00.000000000Z [DEBUG] BACKTEST_TRADER-001.OrderMatchingEngine(NSE): Processing QuoteTick(BANKNIFTY.OPT.26Jun2025.56200.CALL.NSE,33206.00,33624.00,1,1,1750248000000000000)
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: === RECEIVED QUOTE TICK: BANKNIFTY.OPT.26Jun2025.56200.CALL.NSE,33206.00,33624.00,1,1,1750248000000000000 ===
# 2025-06-18T12:00:00.000000000Z [DEBUG] BACKTEST_TRADER-001.OrderMatchingEngine(NSE): Processing QuoteTick(BANKNIFTY.OPT.26Jun2025.56100.CALL.NSE,38501.00,37959.00,1,1,1750248000000000000)
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: === RECEIVED QUOTE TICK: BANKNIFTY.OPT.26Jun2025.56100.CALL.NSE,38501.00,37959.00,1,1,1750248000000000000 ===
# 2025-06-18T12:00:00.000000000Z [DEBUG] BACKTEST_TRADER-001.OrderMatchingEngine(NSE): Processing QuoteTick(BANKNIFTY.OPT.26Jun2025.45500.CALL.NSE,988800.00,1047660.00,1,1,1750248000000000000)
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: === RECEIVED QUOTE TICK: BANKNIFTY.OPT.26Jun2025.45500.CALL.NSE,988800.00,1047660.00,1,1,1750248000000000000 ===
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: *** ENTRY TRIGGERED! *** Price: 1018230.00, IV: 16.3670, OI: 0
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: <--[EVT] OrderInitialized(instrument_id=BANKNIFTY.OPT.26Jun2025.64000.CALL.NSE, client_order_id=O-20250618-120000-001-000-4, side=BUY, type=MARKET, quantity=1, time_in_force=DAY, post_only=False, reduce_only=False, quote_quantity=False, options={}, emulation_trigger=NO_TRIGGER, trigger_instrument_id=None, contingency_type=NO_CONTINGENCY, order_list_id=None, linked_order_ids=None, parent_order_id=None, exec_algorithm_id=None, exec_algorithm_params=None, exec_spawn_id=None, tags=['entry-long-3'])
# 2025-06-18T12:00:00.000000000Z [DEBUG] BACKTEST_TRADER-001.Cache: Added MarketOrder(BUY 1 BANKNIFTY.OPT.26Jun2025.64000.CALL.NSE MARKET DAY, status=INITIALIZED, client_order_id=O-20250618-120000-001-000-4, venue_order_id=None, position_id=None, tags=['entry-long-3'])
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: [CMD]--> [Risk] SubmitOrder(order=MarketOrder(BUY 1 BANKNIFTY.OPT.26Jun2025.64000.CALL.NSE MARKET DAY, status=INITIALIZED, client_order_id=O-20250618-120000-001-000-4, venue_order_id=None, position_id=None, tags=['entry-long-3']), position_id=None)
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: <--[EVT] OrderSubmitted(instrument_id=BANKNIFTY.OPT.26Jun2025.64000.CALL.NSE, client_order_id=O-20250618-120000-001-000-4, account_id=NSE-001, ts_event=1750248000000000000)
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: Market order submitted successfully: MarketOrder(BUY 1 BANKNIFTY.OPT.26Jun2025.64000.CALL.NSE MARKET DAY, status=SUBMITTED, client_order_id=O-20250618-120000-001-000-4, venue_order_id=None, position_id=None, tags=['entry-long-3'])
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: Trade parameters set - Entry: 1018230.00, SL: 33415.00, TP: 1018535.47
# 2025-06-18T12:00:00.000000000Z [WARN] BACKTEST_TRADER-001.MyNSEStrategy: <--[EVT] OrderRejected(instrument_id=BANKNIFTY.OPT.26Jun2025.64000.CALL.NSE, client_order_id=O-20250618-120000-001-000-4, account_id=NSE-001, reason='no market for BANKNIFTY.OPT.26Jun2025.64000.CALL.NSE', ts_event=1750248000000000000)
# 2025-06-18T12:00:00.000000000Z [DEBUG] BACKTEST_TRADER-001.OrderMatchingEngine(NSE): Processing QuoteTick(BANKNIFTY.OPT.26Jun2025.47000.CALL.NSE,857030.00,895205.00,1,1,1750248000000000000)
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: === RECEIVED QUOTE TICK: BANKNIFTY.OPT.26Jun2025.47000.CALL.NSE,857030.00,895205.00,1,1,1750248000000000000 ===
# 2025-06-18T12:00:00.000000000Z [DEBUG] BACKTEST_TRADER-001.OrderMatchingEngine(NSE): Processing QuoteTick(BANKNIFTY.OPT.26Jun2025.50000.CALL.NSE,578037.00,593330.00,1,1,1750248000000000000)
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: === RECEIVED QUOTE TICK: BANKNIFTY.OPT.26Jun2025.50000.CALL.NSE,578037.00,593330.00,1,1,1750248000000000000 ===
# 2025-06-18T12:00:00.000000000Z [DEBUG] BACKTEST_TRADER-001.OrderMatchingEngine(NSE): Processing QuoteTick(BANKNIFTY.OPT.26Jun2025.56000.CALL.NSE,42067.00,42662.00,1,1,1750248000000000000)
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: === RECEIVED QUOTE TICK: BANKNIFTY.OPT.26Jun2025.56000.CALL.NSE,42067.00,42662.00,1,1,1750248000000000000 ===
# 2025-06-18T12:00:00.000000000Z [DEBUG] BACKTEST_TRADER-001.OrderMatchingEngine(NSE): Processing QuoteTick(BANKNIFTY.OPT.26Jun2025.55900.CALL.NSE,48398.00,48299.00,1,1,1750248000000000000)
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: === RECEIVED QUOTE TICK: BANKNIFTY.OPT.26Jun2025.55900.CALL.NSE,48398.00,48299.00,1,1,1750248000000000000 ===
# 2025-06-18T12:00:00.000000000Z [DEBUG] BACKTEST_TRADER-001.OrderMatchingEngine(NSE): Processing QuoteTick(BANKNIFTY.OPT.26Jun2025.49900.CALL.NSE,562873.00,617419.00,1,1,1750248000000000000)
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: === RECEIVED QUOTE TICK: BANKNIFTY.OPT.26Jun2025.49900.CALL.NSE,562873.00,617419.00,1,1,1750248000000000000 ===
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: *** ENTRY TRIGGERED! *** Price: 590146.00, IV: 21.6747, OI: 0
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: <--[EVT] OrderInitialized(instrument_id=BANKNIFTY.OPT.26Jun2025.64000.CALL.NSE, client_order_id=O-20250618-120000-001-000-5, side=BUY, type=MARKET, quantity=1, time_in_force=DAY, post_only=False, reduce_only=False, quote_quantity=False, options={}, emulation_trigger=NO_TRIGGER, trigger_instrument_id=None, contingency_type=NO_CONTINGENCY, order_list_id=None, linked_order_ids=None, parent_order_id=None, exec_algorithm_id=None, exec_algorithm_params=None, exec_spawn_id=None, tags=['entry-long-4'])
# 2025-06-18T12:00:00.000000000Z [DEBUG] BACKTEST_TRADER-001.Cache: Added MarketOrder(BUY 1 BANKNIFTY.OPT.26Jun2025.64000.CALL.NSE MARKET DAY, status=INITIALIZED, client_order_id=O-20250618-120000-001-000-5, venue_order_id=None, position_id=None, tags=['entry-long-4'])
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: [CMD]--> [Risk] SubmitOrder(order=MarketOrder(BUY 1 BANKNIFTY.OPT.26Jun2025.64000.CALL.NSE MARKET DAY, status=INITIALIZED, client_order_id=O-20250618-120000-001-000-5, venue_order_id=None, position_id=None, tags=['entry-long-4']), position_id=None)
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: <--[EVT] OrderSubmitted(instrument_id=BANKNIFTY.OPT.26Jun2025.64000.CALL.NSE, client_order_id=O-20250618-120000-001-000-5, account_id=NSE-001, ts_event=1750248000000000000)
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: Market order submitted successfully: MarketOrder(BUY 1 BANKNIFTY.OPT.26Jun2025.64000.CALL.NSE MARKET DAY, status=SUBMITTED, client_order_id=O-20250618-120000-001-000-5, venue_order_id=None, position_id=None, tags=['entry-long-4'])
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: Trade parameters set - Entry: 590146.00, SL: 42364.50, TP: 590323.04
# 2025-06-18T12:00:00.000000000Z [WARN] BACKTEST_TRADER-001.MyNSEStrategy: <--[EVT] OrderRejected(instrument_id=BANKNIFTY.OPT.26Jun2025.64000.CALL.NSE, client_order_id=O-20250618-120000-001-000-5, account_id=NSE-001, reason='no market for BANKNIFTY.OPT.26Jun2025.64000.CALL.NSE', ts_event=1750248000000000000)
# 2025-06-18T12:00:00.000000000Z [DEBUG] BACKTEST_TRADER-001.OrderMatchingEngine(NSE): Processing QuoteTick(BANKNIFTY.OPT.26Jun2025.55800.CALL.NSE,53302.00,52178.00,1,1,1750248000000000000)
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: === RECEIVED QUOTE TICK: BANKNIFTY.OPT.26Jun2025.55800.CALL.NSE,53302.00,52178.00,1,1,1750248000000000000 ===
# 2025-06-18T12:00:00.000000000Z [DEBUG] BACKTEST_TRADER-001.OrderMatchingEngine(NSE): Processing QuoteTick(BANKNIFTY.OPT.26Jun2025.55700.CALL.NSE,57832.00,59621.00,1,1,1750248000000000000)
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: === RECEIVED QUOTE TICK: BANKNIFTY.OPT.26Jun2025.55700.CALL.NSE,57832.00,59621.00,1,1,1750248000000000000 ===
# 2025-06-18T12:00:00.000000000Z [DEBUG] BACKTEST_TRADER-001.OrderMatchingEngine(NSE): Processing QuoteTick(BANKNIFTY.OPT.26Jun2025.46900.CALL.NSE,851430.00,922452.00,1,1,1750248000000000000)
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: === RECEIVED QUOTE TICK: BANKNIFTY.OPT.26Jun2025.46900.CALL.NSE,851430.00,922452.00,1,1,1750248000000000000 ===
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: *** ENTRY TRIGGERED! *** Price: 886941.00, IV: 25.3533, OI: 0
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: <--[EVT] OrderInitialized(instrument_id=BANKNIFTY.OPT.26Jun2025.64000.CALL.NSE, client_order_id=O-20250618-120000-001-000-6, side=BUY, type=MARKET, quantity=1, time_in_force=DAY, post_only=False, reduce_only=False, quote_quantity=False, options={}, emulation_trigger=NO_TRIGGER, trigger_instrument_id=None, contingency_type=NO_CONTINGENCY, order_list_id=None, linked_order_ids=None, parent_order_id=None, exec_algorithm_id=None, exec_algorithm_params=None, exec_spawn_id=None, tags=['entry-long-5'])
# 2025-06-18T12:00:00.000000000Z [DEBUG] BACKTEST_TRADER-001.Cache: Added MarketOrder(BUY 1 BANKNIFTY.OPT.26Jun2025.64000.CALL.NSE MARKET DAY, status=INITIALIZED, client_order_id=O-20250618-120000-001-000-6, venue_order_id=None, position_id=None, tags=['entry-long-5'])
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: [CMD]--> [Risk] SubmitOrder(order=MarketOrder(BUY 1 BANKNIFTY.OPT.26Jun2025.64000.CALL.NSE MARKET DAY, status=INITIALIZED, client_order_id=O-20250618-120000-001-000-6, venue_order_id=None, position_id=None, tags=['entry-long-5']), position_id=None)
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: <--[EVT] OrderSubmitted(instrument_id=BANKNIFTY.OPT.26Jun2025.64000.CALL.NSE, client_order_id=O-20250618-120000-001-000-6, account_id=NSE-001, ts_event=1750248000000000000)
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: Market order submitted successfully: MarketOrder(BUY 1 BANKNIFTY.OPT.26Jun2025.64000.CALL.NSE MARKET DAY, status=SUBMITTED, client_order_id=O-20250618-120000-001-000-6, venue_order_id=None, position_id=None, tags=['entry-long-5'])
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: Trade parameters set - Entry: 886941.00, SL: 52740.00, TP: 887207.08
# 2025-06-18T12:00:00.000000000Z [WARN] BACKTEST_TRADER-001.MyNSEStrategy: <--[EVT] OrderRejected(instrument_id=BANKNIFTY.OPT.26Jun2025.64000.CALL.NSE, client_order_id=O-20250618-120000-001-000-6, account_id=NSE-001, reason='no market for BANKNIFTY.OPT.26Jun2025.64000.CALL.NSE', ts_event=1750248000000000000)
# 2025-06-18T12:00:00.000000000Z [DEBUG] BACKTEST_TRADER-001.OrderMatchingEngine(NSE): Processing QuoteTick(BANKNIFTY.OPT.26Jun2025.49800.CALL.NSE,570423.00,615120.00,1,1,1750248000000000000)
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: === RECEIVED QUOTE TICK: BANKNIFTY.OPT.26Jun2025.49800.CALL.NSE,570423.00,615120.00,1,1,1750248000000000000 ===
# 2025-06-18T12:00:00.000000000Z [DEBUG] BACKTEST_TRADER-001.OrderMatchingEngine(NSE): Processing QuoteTick(BANKNIFTY.OPT.26Jun2025.55600.CALL.NSE,64724.00,64067.00,1,1,1750248000000000000)
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: === RECEIVED QUOTE TICK: BANKNIFTY.OPT.26Jun2025.55600.CALL.NSE,64724.00,64067.00,1,1,1750248000000000000 ===
# 2025-06-18T12:00:00.000000000Z [DEBUG] BACKTEST_TRADER-001.OrderMatchingEngine(NSE): Processing QuoteTick(BANKNIFTY.OPT.26Jun2025.55500.CALL.NSE,71883.00,71647.00,1,1,1750248000000000000)
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: === RECEIVED QUOTE TICK: BANKNIFTY.OPT.26Jun2025.55500.CALL.NSE,71883.00,71647.00,1,1,1750248000000000000 ===
# 2025-06-18T12:00:00.000000000Z [DEBUG] BACKTEST_TRADER-001.OrderMatchingEngine(NSE): Processing QuoteTick(BANKNIFTY.OPT.26Jun2025.49700.CALL.NSE,578917.00,654151.00,1,1,1750248000000000000)
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: === RECEIVED QUOTE TICK: BANKNIFTY.OPT.26Jun2025.49700.CALL.NSE,578917.00,654151.00,1,1,1750248000000000000 ===
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: *** ENTRY TRIGGERED! *** Price: 616534.00, IV: 15.3161, OI: 0
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: <--[EVT] OrderInitialized(instrument_id=BANKNIFTY.OPT.26Jun2025.64000.CALL.NSE, client_order_id=O-20250618-120000-001-000-7, side=BUY, type=MARKET, quantity=1, time_in_force=DAY, post_only=False, reduce_only=False, quote_quantity=False, options={}, emulation_trigger=NO_TRIGGER, trigger_instrument_id=None, contingency_type=NO_CONTINGENCY, order_list_id=None, linked_order_ids=None, parent_order_id=None, exec_algorithm_id=None, exec_algorithm_params=None, exec_spawn_id=None, tags=['entry-long-6'])
# 2025-06-18T12:00:00.000000000Z [DEBUG] BACKTEST_TRADER-001.Cache: Added MarketOrder(BUY 1 BANKNIFTY.OPT.26Jun2025.64000.CALL.NSE MARKET DAY, status=INITIALIZED, client_order_id=O-20250618-120000-001-000-7, venue_order_id=None, position_id=None, tags=['entry-long-6'])
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: [CMD]--> [Risk] SubmitOrder(order=MarketOrder(BUY 1 BANKNIFTY.OPT.26Jun2025.64000.CALL.NSE MARKET DAY, status=INITIALIZED, client_order_id=O-20250618-120000-001-000-7, venue_order_id=None, position_id=None, tags=['entry-long-6']), position_id=None)
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: <--[EVT] OrderSubmitted(instrument_id=BANKNIFTY.OPT.26Jun2025.64000.CALL.NSE, client_order_id=O-20250618-120000-001-000-7, account_id=NSE-001, ts_event=1750248000000000000)
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: Market order submitted successfully: MarketOrder(BUY 1 BANKNIFTY.OPT.26Jun2025.64000.CALL.NSE MARKET DAY, status=SUBMITTED, client_order_id=O-20250618-120000-001-000-7, venue_order_id=None, position_id=None, tags=['entry-long-6'])
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: Trade parameters set - Entry: 616534.00, SL: 64395.50, TP: 616718.96
# 2025-06-18T12:00:00.000000000Z [WARN] BACKTEST_TRADER-001.MyNSEStrategy: <--[EVT] OrderRejected(instrument_id=BANKNIFTY.OPT.26Jun2025.64000.CALL.NSE, client_order_id=O-20250618-120000-001-000-7, account_id=NSE-001, reason='no market for BANKNIFTY.OPT.26Jun2025.64000.CALL.NSE', ts_event=1750248000000000000)
# 2025-06-18T12:00:00.000000000Z [DEBUG] BACKTEST_TRADER-001.OrderMatchingEngine(NSE): Processing QuoteTick(BANKNIFTY.OPT.26Jun2025.55400.CALL.NSE,78737.00,78021.00,1,1,1750248000000000000)
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: === RECEIVED QUOTE TICK: BANKNIFTY.OPT.26Jun2025.55400.CALL.NSE,78737.00,78021.00,1,1,1750248000000000000 ===
# 2025-06-18T12:00:00.000000000Z [DEBUG] BACKTEST_TRADER-001.OrderMatchingEngine(NSE): Processing QuoteTick(BANKNIFTY.OPT.26Jun2025.55300.CALL.NSE,86591.00,85660.00,1,1,1750248000000000000)
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: === RECEIVED QUOTE TICK: BANKNIFTY.OPT.26Jun2025.55300.CALL.NSE,86591.00,85660.00,1,1,1750248000000000000 ===
# 2025-06-18T12:00:00.000000000Z [DEBUG] BACKTEST_TRADER-001.OrderMatchingEngine(NSE): Processing QuoteTick(BANKNIFTY.OPT.26Jun2025.44000.CALL.NSE,1164985.00,1179822.00,1,1,1750248000000000000)
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: === RECEIVED QUOTE TICK: BANKNIFTY.OPT.26Jun2025.44000.CALL.NSE,1164985.00,1179822.00,1,1,1750248000000000000 ===
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: *** ENTRY TRIGGERED! *** Price: 1172403.50, IV: 22.3716, OI: 0
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: <--[EVT] OrderInitialized(instrument_id=BANKNIFTY.OPT.26Jun2025.64000.CALL.NSE, client_order_id=O-20250618-120000-001-000-8, side=BUY, type=MARKET, quantity=1, time_in_force=DAY, post_only=False, reduce_only=False, quote_quantity=False, options={}, emulation_trigger=NO_TRIGGER, trigger_instrument_id=None, contingency_type=NO_CONTINGENCY, order_list_id=None, linked_order_ids=None, parent_order_id=None, exec_algorithm_id=None, exec_algorithm_params=None, exec_spawn_id=None, tags=['entry-long-7'])
# 2025-06-18T12:00:00.000000000Z [DEBUG] BACKTEST_TRADER-001.Cache: Added MarketOrder(BUY 1 BANKNIFTY.OPT.26Jun2025.64000.CALL.NSE MARKET DAY, status=INITIALIZED, client_order_id=O-20250618-120000-001-000-8, venue_order_id=None, position_id=None, tags=['entry-long-7'])
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: [CMD]--> [Risk] SubmitOrder(order=MarketOrder(BUY 1 BANKNIFTY.OPT.26Jun2025.64000.CALL.NSE MARKET DAY, status=INITIALIZED, client_order_id=O-20250618-120000-001-000-8, venue_order_id=None, position_id=None, tags=['entry-long-7']), position_id=None)
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: <--[EVT] OrderSubmitted(instrument_id=BANKNIFTY.OPT.26Jun2025.64000.CALL.NSE, client_order_id=O-20250618-120000-001-000-8, account_id=NSE-001, ts_event=1750248000000000000)
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: Market order submitted successfully: MarketOrder(BUY 1 BANKNIFTY.OPT.26Jun2025.64000.CALL.NSE MARKET DAY, status=SUBMITTED, client_order_id=O-20250618-120000-001-000-8, venue_order_id=None, position_id=None, tags=['entry-long-7'])
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: Trade parameters set - Entry: 1172403.50, SL: 78379.00, TP: 1172755.22
# 2025-06-18T12:00:00.000000000Z [WARN] BACKTEST_TRADER-001.MyNSEStrategy: <--[EVT] OrderRejected(instrument_id=BANKNIFTY.OPT.26Jun2025.64000.CALL.NSE, client_order_id=O-20250618-120000-001-000-8, account_id=NSE-001, reason='no market for BANKNIFTY.OPT.26Jun2025.64000.CALL.NSE', ts_event=1750248000000000000)
# 2025-06-18T12:00:00.000000000Z [DEBUG] BACKTEST_TRADER-001.OrderMatchingEngine(NSE): Processing QuoteTick(BANKNIFTY.OPT.26Jun2025.45400.CALL.NSE,996436.00,1046010.00,1,1,1750248000000000000)
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: === RECEIVED QUOTE TICK: BANKNIFTY.OPT.26Jun2025.45400.CALL.NSE,996436.00,1046010.00,1,1,1750248000000000000 ===
# 2025-06-18T12:00:00.000000000Z [DEBUG] BACKTEST_TRADER-001.OrderMatchingEngine(NSE): Processing QuoteTick(BANKNIFTY.OPT.26Jun2025.46800.CALL.NSE,849594.00,946722.00,1,1,1750248000000000000)
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: === RECEIVED QUOTE TICK: BANKNIFTY.OPT.26Jun2025.46800.CALL.NSE,849594.00,946722.00,1,1,1750248000000000000 ===
# 2025-06-18T12:00:00.000000000Z [DEBUG] BACKTEST_TRADER-001.OrderMatchingEngine(NSE): Processing QuoteTick(BANKNIFTY.OPT.26Jun2025.49600.CALL.NSE,596196.00,643517.00,1,1,1750248000000000000)
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: === RECEIVED QUOTE TICK: BANKNIFTY.OPT.26Jun2025.49600.CALL.NSE,596196.00,643517.00,1,1,1750248000000000000 ===
# 2025-06-18T12:00:00.000000000Z [DEBUG] BACKTEST_TRADER-001.OrderMatchingEngine(NSE): Processing QuoteTick(BANKNIFTY.OPT.26Jun2025.55200.CALL.NSE,90745.00,94068.00,1,1,1750248000000000000)
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: === RECEIVED QUOTE TICK: BANKNIFTY.OPT.26Jun2025.55200.CALL.NSE,90745.00,94068.00,1,1,1750248000000000000 ===
# 2025-06-18T12:00:00.000000000Z [DEBUG] BACKTEST_TRADER-001.OrderMatchingEngine(NSE): Processing QuoteTick(BANKNIFTY.OPT.26Jun2025.55100.CALL.NSE,101992.00,101484.00,1,1,1750248000000000000)
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: === RECEIVED QUOTE TICK: BANKNIFTY.OPT.26Jun2025.55100.CALL.NSE,101992.00,101484.00,1,1,1750248000000000000 ===
# 2025-06-18T12:00:00.000000000Z [DEBUG] BACKTEST_TRADER-001.OrderMatchingEngine(NSE): Processing QuoteTick(BANKNIFTY.OPT.26Jun2025.49500.CALL.NSE,632535.00,650530.00,1,1,1750248000000000000)
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: === RECEIVED QUOTE TICK: BANKNIFTY.OPT.26Jun2025.49500.CALL.NSE,632535.00,650530.00,1,1,1750248000000000000 ===
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: *** ENTRY TRIGGERED! *** Price: 641532.50, IV: 32.4063, OI: 0
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: <--[EVT] OrderInitialized(instrument_id=BANKNIFTY.OPT.26Jun2025.64000.CALL.NSE, client_order_id=O-20250618-120000-001-000-9, side=BUY, type=MARKET, quantity=1, time_in_force=DAY, post_only=False, reduce_only=False, quote_quantity=False, options={}, emulation_trigger=NO_TRIGGER, trigger_instrument_id=None, contingency_type=NO_CONTINGENCY, order_list_id=None, linked_order_ids=None, parent_order_id=None, exec_algorithm_id=None, exec_algorithm_params=None, exec_spawn_id=None, tags=['entry-long-8'])
# 2025-06-18T12:00:00.000000000Z [DEBUG] BACKTEST_TRADER-001.Cache: Added MarketOrder(BUY 1 BANKNIFTY.OPT.26Jun2025.64000.CALL.NSE MARKET DAY, status=INITIALIZED, client_order_id=O-20250618-120000-001-000-9, venue_order_id=None, position_id=None, tags=['entry-long-8'])
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: [CMD]--> [Risk] SubmitOrder(order=MarketOrder(BUY 1 BANKNIFTY.OPT.26Jun2025.64000.CALL.NSE MARKET DAY, status=INITIALIZED, client_order_id=O-20250618-120000-001-000-9, venue_order_id=None, position_id=None, tags=['entry-long-8']), position_id=None)
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: <--[EVT] OrderSubmitted(instrument_id=BANKNIFTY.OPT.26Jun2025.64000.CALL.NSE, client_order_id=O-20250618-120000-001-000-9, account_id=NSE-001, ts_event=1750248000000000000)
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: Market order submitted successfully: MarketOrder(BUY 1 BANKNIFTY.OPT.26Jun2025.64000.CALL.NSE MARKET DAY, status=SUBMITTED, client_order_id=O-20250618-120000-001-000-9, venue_order_id=None, position_id=None, tags=['entry-long-8'])
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: Trade parameters set - Entry: 641532.50, SL: 92406.50, TP: 641724.96
# 2025-06-18T12:00:00.000000000Z [WARN] BACKTEST_TRADER-001.MyNSEStrategy: <--[EVT] OrderRejected(instrument_id=BANKNIFTY.OPT.26Jun2025.64000.CALL.NSE, client_order_id=O-20250618-120000-001-000-9, account_id=NSE-001, reason='no market for BANKNIFTY.OPT.26Jun2025.64000.CALL.NSE', ts_event=1750248000000000000)
# 2025-06-18T12:00:00.000000000Z [DEBUG] BACKTEST_TRADER-001.OrderMatchingEngine(NSE): Processing QuoteTick(BANKNIFTY.OPT.26Jun2025.55000.CALL.NSE,108863.00,109755.00,1,1,1750248000000000000)
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: === RECEIVED QUOTE TICK: BANKNIFTY.OPT.26Jun2025.55000.CALL.NSE,108863.00,109755.00,1,1,1750248000000000000 ===
# 2025-06-18T12:00:00.000000000Z [DEBUG] BACKTEST_TRADER-001.OrderMatchingEngine(NSE): Processing QuoteTick(BANKNIFTY.OPT.26Jun2025.54900.CALL.NSE,114379.00,114830.00,1,1,1750248000000000000)
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: === RECEIVED QUOTE TICK: BANKNIFTY.OPT.26Jun2025.54900.CALL.NSE,114379.00,114830.00,1,1,1750248000000000000 ===
# 2025-06-18T12:00:00.000000000Z [DEBUG] BACKTEST_TRADER-001.OrderMatchingEngine(NSE): Processing QuoteTick(BANKNIFTY.OPT.26Jun2025.46700.CALL.NSE,898394.00,971406.00,1,1,1750248000000000000)
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: === RECEIVED QUOTE TICK: BANKNIFTY.OPT.26Jun2025.46700.CALL.NSE,898394.00,971406.00,1,1,1750248000000000000 ===
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: *** ENTRY TRIGGERED! *** Price: 934900.00, IV: 24.7675, OI: 0
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: <--[EVT] OrderInitialized(instrument_id=BANKNIFTY.OPT.26Jun2025.64000.CALL.NSE, client_order_id=O-20250618-120000-001-000-10, side=BUY, type=MARKET, quantity=1, time_in_force=DAY, post_only=False, reduce_only=False, quote_quantity=False, options={}, emulation_trigger=NO_TRIGGER, trigger_instrument_id=None, contingency_type=NO_CONTINGENCY, order_list_id=None, linked_order_ids=None, parent_order_id=None, exec_algorithm_id=None, exec_algorithm_params=None, exec_spawn_id=None, tags=['entry-long-9'])
# 2025-06-18T12:00:00.000000000Z [DEBUG] BACKTEST_TRADER-001.Cache: Added MarketOrder(BUY 1 BANKNIFTY.OPT.26Jun2025.64000.CALL.NSE MARKET DAY, status=INITIALIZED, client_order_id=O-20250618-120000-001-000-10, venue_order_id=None, position_id=None, tags=['entry-long-9'])
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: [CMD]--> [Risk] SubmitOrder(order=MarketOrder(BUY 1 BANKNIFTY.OPT.26Jun2025.64000.CALL.NSE MARKET DAY, status=INITIALIZED, client_order_id=O-20250618-120000-001-000-10, venue_order_id=None, position_id=None, tags=['entry-long-9']), position_id=None)
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: <--[EVT] OrderSubmitted(instrument_id=BANKNIFTY.OPT.26Jun2025.64000.CALL.NSE, client_order_id=O-20250618-120000-001-000-10, account_id=NSE-001, ts_event=1750248000000000000)
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: Market order submitted successfully: MarketOrder(BUY 1 BANKNIFTY.OPT.26Jun2025.64000.CALL.NSE MARKET DAY, status=SUBMITTED, client_order_id=O-20250618-120000-001-000-10, venue_order_id=None, position_id=None, tags=['entry-long-9'])
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: Trade parameters set - Entry: 934900.00, SL: 109309.00, TP: 935180.47
# 2025-06-18T12:00:00.000000000Z [WARN] BACKTEST_TRADER-001.MyNSEStrategy: <--[EVT] OrderRejected(instrument_id=BANKNIFTY.OPT.26Jun2025.64000.CALL.NSE, client_order_id=O-20250618-120000-001-000-10, account_id=NSE-001, reason='no market for BANKNIFTY.OPT.26Jun2025.64000.CALL.NSE', ts_event=1750248000000000000)
# 2025-06-18T12:00:00.000000000Z [DEBUG] BACKTEST_TRADER-001.OrderMatchingEngine(NSE): Processing QuoteTick(BANKNIFTY.OPT.26Jun2025.49400.CALL.NSE,624811.00,668096.00,1,1,1750248000000000000)
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: === RECEIVED QUOTE TICK: BANKNIFTY.OPT.26Jun2025.49400.CALL.NSE,624811.00,668096.00,1,1,1750248000000000000 ===
# 2025-06-18T12:00:00.000000000Z [DEBUG] BACKTEST_TRADER-001.OrderMatchingEngine(NSE): Processing QuoteTick(BANKNIFTY.OPT.26Jun2025.54800.CALL.NSE,122908.00,123487.00,1,1,1750248000000000000)
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: === RECEIVED QUOTE TICK: BANKNIFTY.OPT.26Jun2025.54800.CALL.NSE,122908.00,123487.00,1,1,1750248000000000000 ===
# 2025-06-18T12:00:00.000000000Z [DEBUG] BACKTEST_TRADER-001.OrderMatchingEngine(NSE): Processing QuoteTick(BANKNIFTY.OPT.26Jun2025.54700.CALL.NSE,131024.00,132426.00,1,1,1750248000000000000)
# 2025-06-18T12:00:00.000000000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: === RECEIVED QUOTE TICK: BANKNIFTY.OPT.26Jun2025.54700.CALL.NSE,131024.00,132426.00,1,1,1750248000000000000 ===
# ...
# 2025-06-18T14:15:00.000000000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: === RECEIVED QUOTE TICK: BANKNIFTY.OPT.26Jun2025.53800.CALL.NSE,208002.00,226463.00,1,1,1750256100000000000 ===
# 2025-06-18T14:15:00.000000000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: Already in trade, skipping entry logic. Position: Position(LONG 1 BANKNIFTY.OPT.26Jun2025.64000.CALL.NSE, id=BANKNIFTY.OPT.26Jun2025.64000.CALL.NSE-MyNSEStrategy-000)
# 2025-06-18T14:15:00.000000000Z [DEBUG] BACKTEST_TRADER-001.OrderMatchingEngine(NSE): Processing QuoteTick(BANKNIFTY.OPT.26Jun2025.46000.CALL.NSE,971816.00,1009216.00,1,1,1750256100000000000)
# 2025-06-18T14:15:00.000000000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: === RECEIVED QUOTE TICK: BANKNIFTY.OPT.26Jun2025.46000.CALL.NSE,971816.00,1009216.00,1,1,1750256100000000000 ===
# 2025-06-18T14:15:00.000000000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: Already in trade, skipping entry logic. Position: Position(LONG 1 BANKNIFTY.OPT.26Jun2025.64000.CALL.NSE, id=BANKNIFTY.OPT.26Jun2025.64000.CALL.NSE-MyNSEStrategy-000)
# 2025-06-18T14:15:00.000000000Z [DEBUG] BACKTEST_TRADER-001.OrderMatchingEngine(NSE): Processing QuoteTick(BANKNIFTY.OPT.26Jun2025.53900.CALL.NSE,191369.00,214241.00,1,1,1750256100000000000)
# 2025-06-18T14:15:00.000000000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: === RECEIVED QUOTE TICK: BANKNIFTY.OPT.26Jun2025.53900.CALL.NSE,191369.00,214241.00,1,1,1750256100000000000 ===
# 2025-06-18T14:15:00.000000000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: Already in trade, skipping entry logic. Position: Position(LONG 1 BANKNIFTY.OPT.26Jun2025.64000.CALL.NSE, id=BANKNIFTY.OPT.26Jun2025.64000.CALL.NSE-MyNSEStrategy-000)
# 2025-06-18T14:15:00.000000000Z [DEBUG] BACKTEST_TRADER-001.OrderMatchingEngine(NSE): Processing QuoteTick(BANKNIFTY.OPT.26Jun2025.46900.CALL.NSE,849510.00,901052.00,1,1,1750256100000000000)
# 2025-06-18T14:15:00.000000000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: === RECEIVED QUOTE TICK: BANKNIFTY.OPT.26Jun2025.46900.CALL.NSE,849510.00,901052.00,1,1,1750256100000000000 ===
# 2025-06-18T14:15:00.000000000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: Already in trade, skipping entry logic. Position: Position(LONG 1 BANKNIFTY.OPT.26Jun2025.64000.CALL.NSE, id=BANKNIFTY.OPT.26Jun2025.64000.CALL.NSE-MyNSEStrategy-000)
# 2025-06-18T14:15:00.000000000Z [DEBUG] BACKTEST_TRADER-001.OrderMatchingEngine(NSE): Processing QuoteTick(BANKNIFTY.OPT.26Jun2025.52300.CALL.NSE,344217.00,369091.00,1,1,1750256100000000000)
# 2025-06-18T14:15:00.000000000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: === RECEIVED QUOTE TICK: BANKNIFTY.OPT.26Jun2025.52300.CALL.NSE,344217.00,369091.00,1,1,1750256100000000000 ===
# 2025-06-18T14:15:00.000000000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: Already in trade, skipping entry logic. Position: Position(LONG 1 BANKNIFTY.OPT.26Jun2025.64000.CALL.NSE, id=BANKNIFTY.OPT.26Jun2025.64000.CALL.NSE-MyNSEStrategy-000)
# 2025-06-18T14:15:00.000000000Z [DEBUG] BACKTEST_TRADER-001.OrderMatchingEngine(NSE): Processing QuoteTick(BANKNIFTY.OPT.26Jun2025.61700.CALL.NSE,409.00,567.00,1,1,1750256100000000000)
# 2025-06-18T14:15:00.000000000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: === RECEIVED QUOTE TICK: BANKNIFTY.OPT.26Jun2025.61700.CALL.NSE,409.00,567.00,1,1,1750256100000000000 ===
# 2025-06-18T14:15:00.000000000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: Already in trade, skipping entry logic. Position: Position(LONG 1 BANKNIFTY.OPT.26Jun2025.64000.CALL.NSE, id=BANKNIFTY.OPT.26Jun2025.64000.CALL.NSE-MyNSEStrategy-000)
# 2025-06-18T14:15:00.000000000Z [DEBUG] BACKTEST_TRADER-001.OrderMatchingEngine(NSE): Processing QuoteTick(BANKNIFTY.OPT.26Jun2025.43000.CALL.NSE,1261373.00,1306455.00,1,1,1750256100000000000)
# 2025-06-18T14:15:00.000000000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: === RECEIVED QUOTE TICK: BANKNIFTY.OPT.26Jun2025.43000.CALL.NSE,1261373.00,1306455.00,1,1,1750256100000000000 ===
# 2025-06-18T14:15:00.000000000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: Already in trade, skipping entry logic. Position: Position(LONG 1 BANKNIFTY.OPT.26Jun2025.64000.CALL.NSE, id=BANKNIFTY.OPT.26Jun2025.64000.CALL.NSE-MyNSEStrategy-000)
# 2025-06-18T14:15:00.000000000Z [DEBUG] BACKTEST_TRADER-001.OrderMatchingEngine(NSE): Processing QuoteTick(BANKNIFTY.OPT.26Jun2025.46700.CALL.NSE,892395.00,953175.00,1,1,1750256100000000000)
# 2025-06-18T14:15:00.000000000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: === RECEIVED QUOTE TICK: BANKNIFTY.OPT.26Jun2025.46700.CALL.NSE,892395.00,953175.00,1,1,1750256100000000000 ===
# 2025-06-18T14:15:00.000000000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: Already in trade, skipping entry logic. Position: Position(LONG 1 BANKNIFTY.OPT.26Jun2025.64000.CALL.NSE, id=BANKNIFTY.OPT.26Jun2025.64000.CALL.NSE-MyNSEStrategy-000)
# 2025-06-18T14:15:00.000000000Z [DEBUG] BACKTEST_TRADER-001.OrderMatchingEngine(NSE): Processing QuoteTick(BANKNIFTY.OPT.26Jun2025.58500.CALL.NSE,1648.00,1779.00,1,1,1750256100000000000)
# 2025-06-18T14:15:00.000000000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: === RECEIVED QUOTE TICK: BANKNIFTY.OPT.26Jun2025.58500.CALL.NSE,1648.00,1779.00,1,1,1750256100000000000 ===
# 2025-06-18T14:15:00.000000000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: Already in trade, skipping entry logic. Position: Position(LONG 1 BANKNIFTY.OPT.26Jun2025.64000.CALL.NSE, id=BANKNIFTY.OPT.26Jun2025.64000.CALL.NSE-MyNSEStrategy-000)
# 2025-06-18T14:15:00.000000000Z [DEBUG] BACKTEST_TRADER-001.OrderMatchingEngine(NSE): Processing QuoteTick(BANKNIFTY.OPT.26Jun2025.45100.CALL.NSE,1013383.00,1092797.00,1,1,1750256100000000000)
# 2025-06-18T14:15:00.000000000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: === RECEIVED QUOTE TICK: BANKNIFTY.OPT.26Jun2025.45100.CALL.NSE,1013383.00,1092797.00,1,1,1750256100000000000 ===
# 2025-06-18T14:15:00.000000000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: Already in trade, skipping entry logic. Position: Position(LONG 1 BANKNIFTY.OPT.26Jun2025.64000.CALL.NSE, id=BANKNIFTY.OPT.26Jun2025.64000.CALL.NSE-MyNSEStrategy-000)
# 2025-06-18T14:15:00.000000000Z [DEBUG] BACKTEST_TRADER-001.OrderMatchingEngine(NSE): Processing QuoteTick(BANKNIFTY.OPT.26Jun2025.47700.CALL.NSE,768193.00,851383.00,1,1,1750256100000000000)
# 2025-06-18T14:15:00.000000000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: === RECEIVED QUOTE TICK: BANKNIFTY.OPT.26Jun2025.47700.CALL.NSE,768193.00,851383.00,1,1,1750256100000000000 ===
# 2025-06-18T14:15:00.000000000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: Already in trade, skipping entry logic. Position: Position(LONG 1 BANKNIFTY.OPT.26Jun2025.64000.CALL.NSE, id=BANKNIFTY.OPT.26Jun2025.64000.CALL.NSE-MyNSEStrategy-000)
# 2025-06-18T14:15:00.000000000Z [DEBUG] BACKTEST_TRADER-001.OrderMatchingEngine(NSE): Processing QuoteTick(BANKNIFTY.OPT.26Jun2025.44900.CALL.NSE,1048552.00,1092810.00,1,1,1750256100000000000)
# 2025-06-18T14:15:00.000000000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: === RECEIVED QUOTE TICK: BANKNIFTY.OPT.26Jun2025.44900.CALL.NSE,1048552.00,1092810.00,1,1,1750256100000000000 ===
# 2025-06-18T14:15:00.000000000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: Already in trade, skipping entry logic. Position: Position(LONG 1 BANKNIFTY.OPT.26Jun2025.64000.CALL.NSE, id=BANKNIFTY.OPT.26Jun2025.64000.CALL.NSE-MyNSEStrategy-000)
# 2025-06-18T14:15:00.000000000Z [DEBUG] BACKTEST_TRADER-001.BACKTEST_TRADER-001: STOPPING
# 2025-06-18T14:15:00.000000000Z [DEBUG] BACKTEST_TRADER-001.MyNSEStrategy: STOPPING
# 2025-06-18T14:15:00.000000000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: Strategy stopped. Total trades: 0
# 2025-06-18T14:15:00.000000000Z [INFO] BACKTEST_TRADER-001.MyNSEStrategy: STOPPED
# 2025-06-18T14:15:00.000000000Z [INFO] BACKTEST_TRADER-001.BACKTEST_TRADER-001: STOPPED
# 2025-06-18T14:15:00.000000000Z [DEBUG] BACKTEST_TRADER-001.DataEngine: STOPPING
# 2025-06-18T14:15:00.000000000Z [DEBUG] BACKTEST_TRADER-001.DataClient-NSE: STOPPING
# 2025-06-18T14:15:00.000000000Z [INFO] BACKTEST_TRADER-001.DataClient-NSE: Disconnecting...
# 2025-06-18T14:15:00.000000000Z [INFO] BACKTEST_TRADER-001.DataClient-NSE: Disconnected
# 2025-06-18T14:15:00.000000000Z [INFO] BACKTEST_TRADER-001.DataClient-NSE: STOPPED
# 2025-06-18T14:15:00.000000000Z [INFO] BACKTEST_TRADER-001.DataEngine: STOPPED
# 2025-06-18T14:15:00.000000000Z [DEBUG] BACKTEST_TRADER-001.RiskEngine: STOPPING
# 2025-06-18T14:15:00.000000000Z [INFO] BACKTEST_TRADER-001.RiskEngine: STOPPED
# 2025-06-18T14:15:00.000000000Z [DEBUG] BACKTEST_TRADER-001.ExecEngine: STOPPING
# 2025-06-18T14:15:00.000000000Z [DEBUG] BACKTEST_TRADER-001.ExecClient-NSE: STOPPING
# 2025-06-18T14:15:00.000000000Z [INFO] BACKTEST_TRADER-001.ExecClient-NSE: Disconnecting...
# 2025-06-18T14:15:00.000000000Z [INFO] BACKTEST_TRADER-001.ExecClient-NSE: Disconnected
# 2025-06-18T14:15:00.000000000Z [INFO] BACKTEST_TRADER-001.ExecClient-NSE: STOPPED
# 2025-06-18T14:15:00.000000000Z [INFO] BACKTEST_TRADER-001.ExecEngine: STOPPED
# 2025-06-18T14:15:00.000000000Z [DEBUG] BACKTEST_TRADER-001.OrderEmulator: STOPPING
# 2025-06-18T14:15:00.000000000Z [INFO] BACKTEST_TRADER-001.OrderEmulator: STOPPED
# 2025-06-22T07:08:56.720763000Z [INFO] BACKTEST_TRADER-001.BacktestEngine: =================================================================
# 2025-06-22T07:08:56.720764000Z [INFO] BACKTEST_TRADER-001.BacktestEngine:  BACKTEST POST-RUN
# 2025-06-22T07:08:56.720765000Z [INFO] BACKTEST_TRADER-001.BacktestEngine: =================================================================
# 2025-06-22T07:08:56.720769000Z [INFO] BACKTEST_TRADER-001.BacktestEngine: Run config ID:  None
# 2025-06-22T07:08:56.720771000Z [INFO] BACKTEST_TRADER-001.BacktestEngine: Run ID:         9152d9d9-89dd-4c4c-a52f-7fbf1e091a3d
# 2025-06-22T07:08:56.720777000Z [INFO] BACKTEST_TRADER-001.BacktestEngine: Run started:    2025-06-22T07:08:56.576173000Z
# 2025-06-22T07:08:56.720778000Z [INFO] BACKTEST_TRADER-001.BacktestEngine: Run finished:   2025-06-22T07:08:56.720587000Z
# 2025-06-22T07:08:56.720967000Z [INFO] BACKTEST_TRADER-001.BacktestEngine: Elapsed time:   0 days 00:00:00.144414
# 2025-06-22T07:08:56.720969000Z [INFO] BACKTEST_TRADER-001.BacktestEngine: Backtest start: 2025-06-18T12:00:00.000000000Z
# 2025-06-22T07:08:56.720970000Z [INFO] BACKTEST_TRADER-001.BacktestEngine: Backtest end:   2025-06-18T14:15:00.000000000Z
# 2025-06-22T07:08:56.720974000Z [INFO] BACKTEST_TRADER-001.BacktestEngine: Backtest range: 0 days 02:15:00
# 2025-06-22T07:08:56.720975000Z [INFO] BACKTEST_TRADER-001.BacktestEngine: Iterations: 1_830
# 2025-06-22T07:08:56.720980000Z [INFO] BACKTEST_TRADER-001.BacktestEngine: Total events: 38
# 2025-06-22T07:08:56.720993000Z [INFO] BACKTEST_TRADER-001.BacktestEngine: Total orders: 19
# 2025-06-22T07:08:56.720998000Z [INFO] BACKTEST_TRADER-001.BacktestEngine: Total positions: 1
# 2025-06-22T07:08:56.721001000Z [INFO] BACKTEST_TRADER-001.BacktestEngine: =================================================================
# 2025-06-22T07:08:56.721002000Z [INFO] BACKTEST_TRADER-001.BacktestEngine:  SimulatedVenue NSE
# 2025-06-22T07:08:56.721003000Z [INFO] BACKTEST_TRADER-001.BacktestEngine: =================================================================
# 2025-06-22T07:08:56.721005000Z [INFO] BACKTEST_TRADER-001.BacktestEngine: MarginAccount(id=NSE-001, type=MARGIN, base=INR)
# 2025-06-22T07:08:56.721006000Z [INFO] BACKTEST_TRADER-001.BacktestEngine: -----------------------------------------------------------------
# 2025-06-22T07:08:56.721006001Z [INFO] BACKTEST_TRADER-001.BacktestEngine: Balances starting:
# 2025-06-22T07:08:56.721011000Z [INFO] BACKTEST_TRADER-001.BacktestEngine: 1_000_000.00 INR
# 2025-06-22T07:08:56.721011001Z [INFO] BACKTEST_TRADER-001.BacktestEngine: -----------------------------------------------------------------
# 2025-06-22T07:08:56.721011002Z [INFO] BACKTEST_TRADER-001.BacktestEngine: Balances ending:
# 2025-06-22T07:08:56.721013000Z [INFO] BACKTEST_TRADER-001.BacktestEngine: 1_000_000.00 INR
# 2025-06-22T07:08:56.721014000Z [INFO] BACKTEST_TRADER-001.BacktestEngine: -----------------------------------------------------------------
# 2025-06-22T07:08:56.721014001Z [INFO] BACKTEST_TRADER-001.BacktestEngine: Commissions:
# 2025-06-22T07:08:56.721015000Z [INFO] BACKTEST_TRADER-001.BacktestEngine: -----------------------------------------------------------------
# 2025-06-22T07:08:56.721016000Z [INFO] BACKTEST_TRADER-001.BacktestEngine: Unrealized PnLs (included in totals):
# 2025-06-22T07:08:56.721039000Z [INFO] BACKTEST_TRADER-001.BacktestEngine: -330.00 INR
# 2025-06-22T07:08:56.721040000Z [INFO] BACKTEST_TRADER-001.BacktestEngine: =================================================================
# 2025-06-22T07:08:56.721041000Z [INFO] BACKTEST_TRADER-001.BacktestEngine:  PORTFOLIO PERFORMANCE
# 2025-06-22T07:08:56.721041001Z [INFO] BACKTEST_TRADER-001.BacktestEngine: =================================================================
# 2025-06-22T07:08:56.728761000Z [INFO] BACKTEST_TRADER-001.BacktestEngine:  PnL Statistics (INR)
# 2025-06-22T07:08:56.728762000Z [INFO] BACKTEST_TRADER-001.BacktestEngine: -----------------------------------------------------------------
# 2025-06-22T07:08:56.729075000Z [INFO] BACKTEST_TRADER-001.BacktestEngine: PnL (total):                    -330.0
# 2025-06-22T07:08:56.729076000Z [INFO] BACKTEST_TRADER-001.BacktestEngine: PnL% (total):                   -0.033
# 2025-06-22T07:08:56.729076001Z [INFO] BACKTEST_TRADER-001.BacktestEngine: Max Winner:                     0.0
# 2025-06-22T07:08:56.729077000Z [INFO] BACKTEST_TRADER-001.BacktestEngine: Avg Winner:                     0.0
# 2025-06-22T07:08:56.729077001Z [INFO] BACKTEST_TRADER-001.BacktestEngine: Min Winner:                     0.0
# 2025-06-22T07:08:56.729077002Z [INFO] BACKTEST_TRADER-001.BacktestEngine: Min Loser:                      0.0
# 2025-06-22T07:08:56.729077003Z [INFO] BACKTEST_TRADER-001.BacktestEngine: Avg Loser:                      0.0
# 2025-06-22T07:08:56.729078000Z [INFO] BACKTEST_TRADER-001.BacktestEngine: Max Loser:                      0.0
# 2025-06-22T07:08:56.729078001Z [INFO] BACKTEST_TRADER-001.BacktestEngine: Expectancy:                     0.0
# 2025-06-22T07:08:56.729078002Z [INFO] BACKTEST_TRADER-001.BacktestEngine: Win Rate:                       0.0
# 2025-06-22T07:08:56.729079000Z [INFO] BACKTEST_TRADER-001.BacktestEngine: -----------------------------------------------------------------
# 2025-06-22T07:08:56.729079001Z [INFO] BACKTEST_TRADER-001.BacktestEngine:  Returns Statistics
# 2025-06-22T07:08:56.729079002Z [INFO] BACKTEST_TRADER-001.BacktestEngine: -----------------------------------------------------------------
# 2025-06-22T07:08:56.737058000Z [INFO] BACKTEST_TRADER-001.BacktestEngine: Returns Volatility (252 days):  nan
# 2025-06-22T07:08:56.737060000Z [INFO] BACKTEST_TRADER-001.BacktestEngine: Average (Return):               nan
# 2025-06-22T07:08:56.737061000Z [INFO] BACKTEST_TRADER-001.BacktestEngine: Average Loss (Return):          nan
# 2025-06-22T07:08:56.737061001Z [INFO] BACKTEST_TRADER-001.BacktestEngine: Average Win (Return):           nan
# 2025-06-22T07:08:56.737061002Z [INFO] BACKTEST_TRADER-001.BacktestEngine: Sharpe Ratio (252 days):        nan
# 2025-06-22T07:08:56.737061003Z [INFO] BACKTEST_TRADER-001.BacktestEngine: Sortino Ratio (252 days):       nan
# 2025-06-22T07:08:56.737062000Z [INFO] BACKTEST_TRADER-001.BacktestEngine: Profit Factor:                  nan
# 2025-06-22T07:08:56.737062001Z [INFO] BACKTEST_TRADER-001.BacktestEngine: Risk Return Ratio:              nan
# 2025-06-22T07:08:56.737063000Z [INFO] BACKTEST_TRADER-001.BacktestEngine: -----------------------------------------------------------------
# 2025-06-22T07:08:56.737063001Z [INFO] BACKTEST_TRADER-001.BacktestEngine:  General Statistics
# 2025-06-22T07:08:56.737064000Z [INFO] BACKTEST_TRADER-001.BacktestEngine: -----------------------------------------------------------------
# 2025-06-22T07:08:56.737081000Z [INFO] BACKTEST_TRADER-001.BacktestEngine: Long Ratio:                     1.00
# 2025-06-22T07:08:56.737082000Z [INFO] BACKTEST_TRADER-001.BacktestEngine: -----------------------------------------------------------------

# %%
# Add debugging to check if strategy receives quote ticks
print("=== CHECKING STRATEGY QUOTE TICK RECEPTION ===")

# Check if strategy has any quote tick count
if hasattr(strategy, '_quote_tick_count'):
    print(f"Strategy quote tick count: {strategy._quote_tick_count}")
else:
    print("Strategy has no _quote_tick_count attribute")

# Check strategy cache for any data
if strategy.cache:
    print(f"Strategy cache orders: {len(strategy.cache.orders())}")
    print(f"Strategy cache positions: {len(strategy.cache.positions())}")
    print(f"Strategy cache has data: {strategy.cache is not None}")
else:
    print("Strategy has no cache")

# Check if strategy has any trades
print(f"Strategy trades: {len(strategy.trades) if hasattr(strategy, 'trades') else 'No trades attribute'}")

# Check engine results using correct attributes
print(f"\nEngine cache orders: {len(engine.cache.orders())}")
print(f"Engine cache positions: {len(engine.cache.positions())}")
print(f"Engine data count: {len(engine.data)}")
print(f"Engine iteration: {engine.iteration}")
# Out:
# === CHECKING STRATEGY QUOTE TICK RECEPTION ===
# Strategy has no _quote_tick_count attribute
# Strategy cache orders: 19
# Strategy cache positions: 1
# Strategy cache has data: True
# Strategy trades: 0
#
# Engine cache orders: 19
# Engine cache positions: 1
# Engine data count: 1830
# Engine iteration: 1830

# %%
# Get the actual trading results
from nautilus_trader.model.identifiers import Venue

print("\n=== TRADING RESULTS ===")

# Strategy trades
if hasattr(strategy, 'trades') and strategy.trades:
    print(f"Strategy trades count: {len(strategy.trades)}")
    print("Strategy trades:")
    for i, trade in enumerate(strategy.trades[:5]):
        print(f"  Trade {i+1}: {trade}")
else:
    print("No strategy trades found.")

# Engine orders
engine_orders = engine.cache.orders()
print(f"\nEngine orders count: {len(engine_orders)}")
if engine_orders:
    print("Engine orders (first 5):")
    for i, order in enumerate(engine_orders[:5]):
        print(f"  Order {i+1}: {order}")

# Engine positions
engine_positions = engine.cache.positions()
print(f"\nEngine positions count: {len(engine_positions)}")
if engine_positions:
    print("Engine positions:")
    for i, position in enumerate(engine_positions):
        print(f"  Position {i+1}: {position}")

# Portfolio details
venue_id = Venue("NSE")
account = engine.portfolio.account(venue_id)

if account:
    print(f"\nPortfolio Balance: {account.balance}")
    print(f"Portfolio Equity: {account.equity}")
    print(f"Margin Used: {account.margin_used}")
    print(f"Margin Available: {account.margin_available}")
else:
    print("\nNo account found for venue NSE.")
# Out:
# === TRADING RESULTS ===
# No strategy trades found.
#
# Engine orders count: 19
# Engine orders (first 5):
#   Order 1: MarketOrder(BUY 1 BANKNIFTY.OPT.26Jun2025.64000.CALL.NSE MARKET DAY, status=REJECTED, client_order_id=O-20250618-120000-001-000-1, venue_order_id=None, position_id=None, tags=['entry-long-0'])
#   Order 2: MarketOrder(BUY 1 BANKNIFTY.OPT.26Jun2025.64000.CALL.NSE MARKET DAY, status=REJECTED, client_order_id=O-20250618-120000-001-000-10, venue_order_id=None, position_id=None, tags=['entry-long-9'])
#   Order 3: MarketOrder(BUY 1 BANKNIFTY.OPT.26Jun2025.64000.CALL.NSE MARKET DAY, status=REJECTED, client_order_id=O-20250618-120000-001-000-11, venue_order_id=None, position_id=None, tags=['entry-long-10'])
#   Order 4: MarketOrder(BUY 1 BANKNIFTY.OPT.26Jun2025.64000.CALL.NSE MARKET DAY, status=REJECTED, client_order_id=O-20250618-120000-001-000-12, venue_order_id=None, position_id=None, tags=['entry-long-11'])
#   Order 5: MarketOrder(BUY 1 BANKNIFTY.OPT.26Jun2025.64000.CALL.NSE MARKET DAY, status=REJECTED, client_order_id=O-20250618-120000-001-000-13, venue_order_id=None, position_id=None, tags=['entry-long-12'])
#
# Engine positions count: 1
# Engine positions:
#   Position 1: Position(LONG 1 BANKNIFTY.OPT.26Jun2025.64000.CALL.NSE, id=BANKNIFTY.OPT.26Jun2025.64000.CALL.NSE-MyNSEStrategy-000)
#
# Portfolio Balance: <bound method Account.balance of MarginAccount(id=NSE-001, type=MARGIN, base=INR)>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[19], line 37
#      35 if account:
#      36     print(f"\nPortfolio Balance: {account.balance}")
# ---> 37     print(f"Portfolio Equity: {account.equity}")
#      38     print(f"Margin Used: {account.margin_used}")
#      39     print(f"Margin Available: {account.margin_available}")
#
# AttributeError: 'nautilus_trader.accounting.accounts.margin.MarginAccount' object has no attribute 'equity'

# %%
# View trades
strategy.trades[:5]

# %%
# 5. Analyze results
# You can now access engine.orders, engine.trades, engine.portfolio, etc.
print("Orders:", engine.orders)
print("Trades:", engine.trades)
print("Portfolio:", engine.portfolio)

# %%
engine.reset()

# %%
engine.reset()

# %%
engine.dispose()
